# %%
# ===================================================================
#  Library
# ===================================================================
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy as sp
import seaborn as sns

# %%
# ===================================================================
#  data
# ===================================================================
data_1 = pd.DataFrame(
    data=zip(
        [45.49498124624943, 
         44.364568837517524,
         44.706570976834534,
         44.33097999776283,
         44.33737773847836,
         44.19084497334044,
         44.15693790827101,
         44.17021540173626,
         44.00756302577998,
         43.966795960812284,
         43.885207515251004,
         43.87820413829381,
         43.81098308181197,
         43.707553358225496,
         43.85695527186413,
         43.805041424202756,
         43.71498987687226,
         43.723440087378485,
         43.69660836605411,
         43.56925636218776,
         43.572764461334195,
         43.581332152377506,
         43.58019939649411
         ],
        [44.7311468, 
         43.7384163,
         44.0149739,
         43.7719024,
         43.7822822,
         43.6761545,         
         43.6017463,
         43.6111546,
         43.5427417,
         43.4672241,
         43.4107321,
         43.4288652,
         43.5309316,
         43.3956187,
         43.4045397,
         43.5306013,
         43.4082446,
         43.3202885,
         43.2657786,
         43.2500502,
         43.2432630,
         43.2406218,
         43.2620733,
         ],
        ),
    columns=["CV", "LB"]
)


data_2 = pd.DataFrame(
    data=zip(
        [44.22,      # kun4qi exp033
         44.21,      # kun4qi exp034
         44.26,      # kun4qi exp034
         44.29,      # kun4qi exp036
         44.03,      # kun4qi exp038
         44.14,      # kun4qi exp039
         44.0131,    # kun4qi exp038とexp039のアンサンブル
         44.0024,
         ],
        [43.5922432,    # kun4qi exp033
         43.6287746,    # kun4qi exp034
         43.6185727,    # kun4qi exp034
         43.6194139,    # kun4qi exp036
         43.4753345,    # kun4qi exp038
         43.5001031,    # kun4qi exp039  
         43.4744768,    # kun4qi exp038とexp039のアンサンブル
         43.4715297
         ],
        ),
    columns=["CV", "LB"]
)
print(sp.stats.pearsonr(data_1["LB"][2:], data_1["CV"][2:])[0])
print(sp.stats.pearsonr(data_2["LB"], data_2["CV"])[0])
# Out:
# 0.9684069985342803
# 0.943271029183636

# %%
# グラフの設定
fig, ax = plt.subplots(figsize=(8, 5))

# 回帰曲線をプロット
sns.regplot(x=data_2["CV"], y=data_2["LB"], ax=ax, scatter=True, label="Kun4qi", ci=None)
sns.regplot(x=data_1["CV"][2:], y=data_1["LB"][2:], ax=ax, scatter=True, label="Yuji.K", ci=None)

# グラフのタイトルやラベルなどを設定
ax.set_title("Scatter plot with Regression Lines")
ax.set_xlabel("CV")
ax.set_ylabel("LB")
ax.legend()
plt.grid()

# グラフを表示
plt.show()

# %%
# グラフの設定
data = pd.concat([data_1, data_2], ignore_index=True)
fig, ax = plt.subplots(figsize=(8, 5))

# 回帰曲線をプロット
#sns.regplot(x=data_2["CV"], y=data_2["LB"], ax=ax, scatter=True, label="Kun4qi", ci=None)
sns.regplot(x=data["CV"], y=data["LB"], ax=ax, scatter=True, label="all", ci=None)

# グラフのタイトルやラベルなどを設定
ax.set_title("Scatter plot with Regression Lines")
ax.set_xlabel("CV")
ax.set_ylabel("LB")
ax.legend()
plt.grid()

# グラフを表示
plt.show()

# %%
# グラフの設定
data = pd.concat([data_1, data_2], ignore_index=True)
fig, ax = plt.subplots(figsize=(8, 5))

# 回帰曲線をプロット
#sns.regplot(x=data_2["CV"], y=data_2["LB"], ax=ax, scatter=True, label="Kun4qi", ci=None)
sns.regplot(x=data["CV"][2:], y=data["LB"][2:], ax=ax, scatter=True, label="all", ci=None)

# グラフのタイトルやラベルなどを設定
ax.set_title("Scatter plot with Regression Lines")
ax.set_xlabel("CV")
ax.set_ylabel("LB")
ax.legend()
plt.grid()

# グラフを表示
plt.show()

# %%
# グラフの設定
data = pd.concat([data_1, data_2], ignore_index=True)
fig, ax = plt.subplots(figsize=(8, 5))

# 回帰曲線をプロット
#sns.regplot(x=data_2["CV"], y=data_2["LB"], ax=ax, scatter=True, label="Kun4qi", ci=None)
sns.regplot(x=data["CV"], y=data["LB"], ax=ax, scatter=True, label="all", ci=None)

# グラフのタイトルやラベルなどを設定
ax.set_title("Scatter plot with Regression Lines")
ax.set_xlabel("CV")
ax.set_ylabel("LB")
ax.legend()
plt.grid()

# グラフを表示
plt.show()

# %%
# グラフの設定
data = pd.concat([data_1, data_2], ignore_index=True)
fig, ax = plt.subplots(figsize=(8, 5))

# 回帰曲線をプロット
#sns.regplot(x=data_2["CV"], y=data_2["LB"], ax=ax, scatter=True, label="Kun4qi", ci=None)
sns.regplot(x=data["CV"][3:], y=data["LB"][3:], ax=ax, scatter=True, label="all", ci=None)

# グラフのタイトルやラベルなどを設定
ax.set_title("Scatter plot with Regression Lines")
ax.set_xlabel("CV")
ax.set_ylabel("LB")
ax.legend()
plt.grid()

# グラフを表示
plt.show()
