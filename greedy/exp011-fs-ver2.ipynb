# %%
# ===================================================================
#  Library
# ===================================================================
import os
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import math
import time


from sklearn.preprocessing import OrdinalEncoder
from sklearn.metrics import mean_absolute_percentage_error
from tqdm.auto import tqdm

import warnings
warnings.simplefilter("ignore")

import unicodedata
# %pip install -U lightgbm
import lightgbm as lgb
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Requirement already satisfied: lightgbm in /opt/conda/lib/python3.10/site-packages (3.3.2)
# Collecting lightgbm
#   Downloading lightgbm-4.0.0-py3-none-manylinux_2_28_x86_64.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 29.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from lightgbm) (1.23.5)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from lightgbm) (1.11.1)
# Installing collected packages: lightgbm
#   Attempting uninstall: lightgbm
#     Found existing installation: lightgbm 3.3.2
#     Uninstalling lightgbm-3.3.2:
#       Successfully uninstalled lightgbm-3.3.2
# Successfully installed lightgbm-4.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# ===================================================================
#  CFG
# ===================================================================
class CFG:
    filename = "exp011"
    seed = 42
    greedy_seed = 778
    n_splits = 5
    data_dir = "/kaggle/input/signate-studentcup2023/"
    year_bins = 20
    num_boost_round = 10000
    stopping_rounds = 1500
    n_trials = 1500
    save_dir = "/kaggle/working/"
    num_cores = 4 # kaggleの方と統一
    categorical_features = [
        "fuel", "title_status", "type", "state", "region", "manufacturer", "condition", "cylinders", "transmission", "drive", "size", "paint_color"
        ]
    candidates = [col + "_category" for col in categorical_features] +\
    ["log_odometer", "sqrt_odometer", "elapsed_years", "log_elapsed_years", "sqrt_elapsed_years", "elapsed_years*odometer",
    "elapsed_years*log_odometer", "elapsed_years*sqrt_odometer", "log_elapsed_years*odometer", "log_elapsed_years*log_odometer", 
     "log_elapsed_years*sqrt_odometer", "sqrt_elapsed_years*odometer", "sqrt_elapsed_years*log_odometer", "sqrt_elapsed_years*sqrt_odometer",
    "region_latitude", "region_longitude", "state_latitude", "state_longitude"]
    use_features = ["odometer", "year"]

# %%
# ===================================================================
#  Utils
# ===================================================================
def seed_everything(seed):
    """fix random factors"""
    random.seed(seed)
    np.random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
seed_everything(CFG.seed)
    

def get_score(y_true, y_pred):
    """get MAPE score"""
    score = mean_absolute_percentage_error(y_true, y_pred)
    return score * 100


def kfold(CFG, all_data: pd.DataFrame):
    """kfold

    Args:
        CFG : config
        all_data (pd.DataFrame)

    Returns:
        train, test
    """
    train = all_data[all_data["flag"] == "train"].reset_index(drop=True)
    test = all_data[all_data["flag"] == "test"].reset_index(drop=True)
    # priceを小さい順に各foldに振り分ける
    train.sort_values(by="price", ignore_index=True, inplace=True)
    train["fold"] = [i for i in range(CFG.n_splits)] * (train.shape[0] // CFG.n_splits) + [i for i in range(train.shape[0] % CFG.n_splits)]
    train.sort_values(by="id", ignore_index=True, inplace=True)
    print(train["fold"].value_counts())
    print("The variance of the mean of the folds: ", train.groupby("fold")["price"].mean().std())
    return train

def asMinutes(s):
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)


def timeSince(since, percent):
    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s
    return '%s (remain %s)' % (asMinutes(s), asMinutes(rs))

# %%
# ===================================================================
#  Data Loading
# ===================================================================
train = pd.read_csv(CFG.data_dir+"train.csv")
test = pd.read_csv(CFG.data_dir+"test.csv")

region_coor = pd.read_csv(CFG.data_dir+"region_coordinate.csv")
state_coor = pd.read_csv(CFG.data_dir+"state_coordinate.csv")

train["flag"] = "train"
test["flag"] = "test"
all_data = pd.concat([train, test], ignore_index=True)

# %%
# ===================================================================
#  feature_engineering
# ===================================================================
def preprocessing(all_data: pd.DataFrame):
    """
    train, testデータで共通の前処理のコード
    
    ・yearの異常値を直す
    ・manufacturerの表記を統一する
    ・sizeの表記を統一する
    ・regionの欠損値をtrain dataの(state, region)の組み合わせから補完する。残った欠損値は調べて補完する。
    ・title_statusとtypeの欠損値処理はとりあえず放置

    Args:
        all_data (pd.DataFrame): pd.concat([train, test], ignore_index=True)
    """
    # year
    year_dict = {
        2999:1999,
        3008:2008,
        3011:2011,
        3015:2015,
        3017:2017,
        3019:2019,
    }
    all_data["year"] = all_data["year"].replace(year_dict)
    
    
    # manufacturer
    all_data["manufacturer"] = all_data["manufacturer"].str.lower().apply(lambda x: unicodedata.normalize('NFKC', x))
    manufacturer_map = {
        'niѕsan':'nissan',
        'nisѕan':'nissan',
        'subαru':'subaru',
        'toyotа':'toyota',
        'sαturn':'saturn',
        'аcura':'acura',
        'vоlkswagen':'volkswagen',
        'lexuѕ':'lexus',
        'ᴄhrysler':'chrysler',
    }
    all_data["manufacturer"] = all_data["manufacturer"].replace(manufacturer_map)
    
    
    # size
    size_dict = {
        "fullーsize":"full-size",
        "midーsize":"mid-size",
        "subーcompact":"sub-compact",
        "full−size":"full-size",
        "mid−size":"mid-size"
    }
    all_data["size"] = all_data["size"].replace(size_dict)
        
    
    # 地域
    ## region -> stateが一意に定まることを確認
    region_state = {region:{} for region in all_data[all_data["flag"]=="train"]['region'].unique()}
    for row, value in all_data[all_data["flag"]=="train"].iterrows():
        if not pd.isna(value['state']):
            if value['state'] not in region_state[value['region']]:
                region_state[value['region']][value['state']] = 1
            else:
                region_state[value['region']][value['state']] += 1
    for region, state_dict in region_state.items():
        if len(state_dict) > 1 or state_dict == {}:
            region_state[region] = pd.NA
        else:
            region_state[region] = list(state_dict.keys())[0]

    ## regionからstateを決定
    all_data['state'] = [region_state[region] if pd.isna(state) else state for region, state in zip(all_data['region'], all_data['state'])]
    all_data.loc[all_data["region"] == "northwest KS", "state"] = "ks"
    all_data.loc[all_data["region"] == "ashtabula", "state"] = "oh"
    all_data.loc[all_data["region"] == "southern WV", "state"] = "wv"
    
    all_data = pd.merge(all_data, region_coor, on="region", how="left")
    all_data = pd.merge(all_data, state_coor, on="state", how="left")
    
    
    # type
    ## 欠損値 train: 456, test: 229
    
    # title_status
    ## 欠損値 train: 456, test: 229
    
    # fuel
    ## 欠損値 train: 1239, test: 1495
    
    
    all_data["elapsed_years"] = 2023 - all_data["year"]
    all_data["log_elapsed_years"] = np.log(all_data["elapsed_years"])
    all_data["sqrt_elapsed_years"] = np.sqrt(all_data["elapsed_years"])
    
    return all_data

all_data = preprocessing(all_data)

# %%
# ===================================================================
#  Cross Validation
# ===================================================================
train = all_data[all_data["flag"] == "train"].reset_index(drop=True)
test = all_data[all_data["flag"] == "test"].reset_index(drop=True)

train.sort_values(by="id", ignore_index=True, inplace=True)

# priceを小さい順に各foldに振り分ける
train.sort_values(by="price", ignore_index=True, inplace=True)
train["fold"] = [i for i in range(CFG.n_splits)] * (train.shape[0] // CFG.n_splits) + [i for i in range(train.shape[0] % CFG.n_splits)]
train.sort_values(by="id", ignore_index=True, inplace=True)
print("The variance of the mean of the folds: ", train.groupby("fold")["price"].mean().std())
# Out:
# The variance of the mean of the folds:  4.695908800203918

# %%
def preprocessing_per_fold(CFG, train:pd.DataFrame, fold: int = 0):
    """foldごとの前処理: leakageを防ぐ

    Args:
        CFG :config
        train (pd.DataFrame): 学習データ
        test (pd.DataFrame, optional): test data Defaults to None.
        fold (int, optional): Defaults to 0.
        predict (bool, optional): 予測するか否か. Defaults to False.
    """
    X_train = train[train["fold"] != fold].reset_index(drop=True)
    X_valid = train[train["fold"] == fold].reset_index(drop=True)    

    # odometerの補正
    ## odometerが100以下or400000以上を異常値と考えて補完する
    ## year_mapがodometerの分散が大きくなる特徴量だったのでこれを利用してodometerを補完する
    fillna_map = X_train[(X_train["odometer"] > 100)&(X_train["odometer"] < 400000)].groupby(["region"])["odometer"].mean().reset_index()
    
    def replace_odometer(df: pd.DataFrame, fillna_map: pd.DataFrame)-> pd.DataFrame:
        """odometerの異常値をfillna_mapを利用して補完する

        Args:
            df (pd.DataFrame): 補完前のデータ
            fillna_map (pd.DataFrame): 補完するデータ

        Returns:
            pd.DataFrame: 補完後のデータ
        """
        df_1 = df[(df["odometer"] < 100)|(df["odometer"] > 400000)].reset_index(drop=True)
        df_2 = df[(df["odometer"] >= 100)&(df["odometer"] <= 400000)].reset_index(drop=True)
        df_1.drop("odometer", inplace=True, axis=1)
        df_1 = pd.merge(df_1, fillna_map, on="region", how="left")
        df = pd.concat([df_1, df_2])
        return df.sort_values("id", ignore_index=True)
    
    
    X_train = replace_odometer(X_train, fillna_map)
    X_valid = replace_odometer(X_valid, fillna_map)
    X_train["odometer"].fillna(X_train["odometer"].mean(), inplace=True)
    X_valid["odometer"].fillna(X_train["odometer"].mean(), inplace=True)
        

    # 交互作用
    def apply_fe(df: pd.DataFrame) -> pd.DataFrame:
        """foldごとの特徴量作成

        Args:
            df (pd.DataFrame)

        Returns:
            pd.DataFrame: 特徴量作成後のdf
        """
        df["log_odometer"] = np.log(df["odometer"])
        df["sqrt_odometer"] = np.sqrt(df["odometer"])
        
        df["elapsed_years*odometer"] = df["elapsed_years"] * df["odometer"]
        df["elapsed_years*log_odometer"] = df["elapsed_years"] * df["log_odometer"]
        df["elapsed_years*sqrt_odometer"] = df["elapsed_years"] * df["sqrt_odometer"]
        
        df["log_elapsed_years*odometer"] = df["log_elapsed_years"] * df["odometer"]
        df["log_elapsed_years*log_odometer"] = df["log_elapsed_years"] * df["log_odometer"]
        df["log_elapsed_years*sqrt_odometer"] = df["log_elapsed_years"] * df["sqrt_odometer"]
        
        df["sqrt_elapsed_years*odometer"] = df["sqrt_elapsed_years"] * df["odometer"]
        df["sqrt_elapsed_years*log_odometer"] = df["sqrt_elapsed_years"] * df["log_odometer"]
        df["sqrt_elapsed_years*sqrt_odometer"] = df["sqrt_elapsed_years"] * df["sqrt_odometer"]
        return df
    X_train = apply_fe(X_train)
    X_valid = apply_fe(X_valid)
        
        
    # カウントエンコーディング
    for col in CFG.categorical_features:
        count_map = X_train[col].value_counts().to_dict()
        X_train[col+"_count_encoding"] = X_train[col].map(count_map)
        X_valid[col+"_count_encoding"] = X_valid[col].map(count_map)
        if fold == 0:
            CFG.candidates.append(col+"_count_encoding")
        
        
    # 集約特徴量を用いたエンコーディング
    for col in CFG.categorical_features:
        for agg_ in ["mean", "std", "max", "min", "median"]:
            fillna_map = X_train.groupby(col)["price"].agg(agg_)
            X_train[col+f"_{agg_}_encoding"] = X_train[col].map(fillna_map)
            X_valid[col+f"_{agg_}_encoding"] = X_valid[col].map(fillna_map)
            if fold == 0:
                CFG.candidates.append(col+f"_{agg_}_encoding")
                
    # 集約特徴量を用いたエンコーディング
    for col in CFG.categorical_features:
        for agg_ in ["mean", "std", "max", "min", "median"]:
            fillna_map = X_train.groupby(col)["odometer"].agg(agg_)
            X_train[col+f"_{agg_}_odometer_encoding"] = X_train[col].map(fillna_map)
            X_valid[col+f"_{agg_}_odometer_encoding"] = X_valid[col].map(fillna_map)
            if fold == 0:
                CFG.candidates.append(col+f"_{agg_}_odometer_encoding")
            if agg_ == "median" or agg_ == "mean":
                X_train[col+f"_{agg_}_odometer_encoding_diff"] = X_train[col+f"_{agg_}_odometer_encoding"] - X_train["odometer"]
                X_valid[col+f"_{agg_}_odometer_encoding_diff"] = X_valid[col+f"_{agg_}_odometer_encoding"] - X_valid["odometer"]
                if fold == 0:
                    CFG.candidates.append(col+f"_{agg_}_odometer_encoding_diff")
                    
                    
    # 集約特徴量を用いたエンコーディング
    for col in CFG.categorical_features:
        for agg_ in ["mean", "std", "max", "min", "median"]:
            fillna_map = X_train.groupby(col)["elapsed_years"].agg(agg_)
            X_train[col+f"_{agg_}_elapsed_years_encoding"] = X_train[col].map(fillna_map)
            X_valid[col+f"_{agg_}_elapsed_years_encoding"] = X_valid[col].map(fillna_map)
            if fold == 0:
                CFG.candidates.append(col+f"_{agg_}_elapsed_years_encoding")
            if agg_ == "median" or agg_ == "mean":
                X_train[col+f"_{agg_}_elapsed_years_encoding_diff"] = X_train[col+f"_{agg_}_elapsed_years_encoding"] - X_train["elapsed_years"]
                X_valid[col+f"_{agg_}_elapsed_years_encoding_diff"] = X_valid[col+f"_{agg_}_elapsed_years_encoding"] - X_valid["elapsed_years"]
                if fold == 0:
                    CFG.candidates.append(col+f"_{agg_}_elapsed_years_encoding_diff")

                
    """
    # target encodingしたやつらの交互作用
    te = [col for col in X_train.columns if "_mean_" in col and "_diff" not in col] 
    for i, col1 in enumerate(tqdm(te)):
        for col2 in te[i:]:
            X_train[f"{col1}*{col2}"] = X_train[col1] * X_train[col2]
            X_valid[f"{col1}*{col2}"] = X_valid[col1] * X_valid[col2]
            if fold == 0:
                CFG.candidates.append(f"{col1}*{col2}")
    """

            
    # OrdinalEncoder: これはfoldごとではなくともよい
    oe = OrdinalEncoder(categories="auto",
                        handle_unknown="use_encoded_value",
                        unknown_value=999,
                        encoded_missing_value=np.nan, # QUESTION: 欠損値は-1に変換する -> NaNに??
                        )
    CFG.categorical_features_ = [feature + "_category" for feature in CFG.categorical_features]
    X_train[CFG.categorical_features_] = oe.fit_transform(X_train[CFG.categorical_features].values)
    X_valid[CFG.categorical_features_] = oe.transform(X_valid[CFG.categorical_features].values)
    return X_train, X_valid

# %%
# ===================================================================
#  preprocessing_per_fold
# ===================================================================
X_train0, X_valid0 = preprocessing_per_fold(CFG, train, 0)
X_train1, X_valid1 = preprocessing_per_fold(CFG, train, 1)
X_train2, X_valid2 = preprocessing_per_fold(CFG, train, 2)
X_train3, X_valid3 = preprocessing_per_fold(CFG, train, 3)
X_train4, X_valid4 = preprocessing_per_fold(CFG, train, 4)

# %%
# ===================================================================
#  check
# ===================================================================
len(CFG.candidates), len(set(CFG.candidates))
# Out:
# (270, 270)

# %%
# ===================================================================
#  evaluate
# ===================================================================
def train_lgb(CFG, lgb_param):
    oof_df = pd.DataFrame()
    for X_train, X_valid in zip([X_train0, X_train1, X_train2, X_train3, X_train4], [X_valid0, X_valid1, X_valid2, X_valid3, X_valid4]):
        # train
        categorical_features = [col for col in CFG.use_features if "_category" in col]
        lgb_train = lgb.Dataset(X_train[CFG.use_features], X_train["price"], categorical_feature = categorical_features,)
        lgb_valid = lgb.Dataset(X_valid[CFG.use_features], X_valid["price"], categorical_feature = categorical_features,)
        model = lgb.train(
                        lgb_param, 
                        lgb_train, 
                        valid_sets=[lgb_valid],
                        categorical_feature = categorical_features,
                        callbacks=[lgb.early_stopping(stopping_rounds=CFG.stopping_rounds, verbose=False),],
                        )

        X_valid[f"pred"] = model.predict(X_valid[CFG.use_features], num_iteration=model.best_iteration)
        oof_df = pd.concat([oof_df, X_valid], ignore_index=True)
    score = get_score(oof_df["price"], oof_df["pred"])
    return score

# %%
# ===================================================================
#  simple greedy forward selection
# ===================================================================
lgb_param = {
    "task":"train",
    "objective": "mape",
    "boosting":"gbdt",
    "num_boost_round": CFG.num_boost_round,
    "learning_rate":0.1, # default: 0.1
    "num_leaves":31, # max number of leaves in one tree ###
    "max_depth":6, # default -1, int: limit the max depth for tree model ##
    "min_child_weight":1e-3, # double: minimal sum hessian in one leaf
    "min_data_in_leaf":20, # minimal number of data in one leaf
    "alpha":0.9, # double, constraints, alpha > 0.0: 
    "colsample_bytree":0.4, # 0 < "colsample_bytree" < 1
    #: LightGBM will randomly select a subset of features on each iteration (tree) if feature_fraction is smaller than 1.0
    "lambda": 0, #lambda_l2 >= 0.0: L2 regularization
    "subsample":1, #0.0 < bagging_fraction <= 1.0
    "num_threads": CFG.num_cores,
    "metric": 'mape',
    "seed" : CFG.seed,
    "verbosity": -1, 
}

print('\033[32m'+"start simple selection"+'\033[0m')
best_score = train_lgb(CFG, lgb_param)
print(f"[{0}/{len(CFG.candidates)}]Base Score: {best_score:.3f}")

start = time.time()
CFG.candidates = np.random.RandomState(CFG.greedy_seed).permutation(CFG.candidates)
for i, col in enumerate(CFG.candidates):
    CFG.use_features.append(col)
    score = train_lgb(CFG, lgb_param)
    if best_score > score:
        print('[{0}/{1}]'
              'Elapsed {remain:s} '
              'Score: {best_score:.4f} -> {score:.4f} '
              '&   selected: {feature}'
              .format(i+1, len(CFG.candidates),
                      remain=timeSince(start, float(i+1)/len(CFG.candidates) ),
                      best_score = best_score,
                      score = score,
                      feature = col
                     )
             )
        best_score = score
    else:
        print('[{0}/{1}]'
              'Elapsed {remain:s} '
              'Score: {best_score:.4f} -> {score:.4f} '
              '& unselected: {feature}'
              .format(i+1, len(CFG.candidates),
                      remain=timeSince(start, float(i+1)/len(CFG.candidates) ),
                      best_score = best_score,
                      score = score,
                      feature = col
                     )
             )
        CFG.use_features.remove(col)
# Out:
# start simple selection
# [0/270]Base Score: 49.505
# [1/270]Elapsed 1m 11s (remain 318m 42s) Score: 49.5053 -> 49.8388 & unselected: paint_color_mean_odometer_encoding_diff
# [2/270]Elapsed 2m 18s (remain 308m 21s) Score: 49.5053 -> 48.7136 &   selected: fuel_std_elapsed_years_encoding
# [3/270]Elapsed 3m 38s (remain 324m 50s) Score: 48.7136 -> 46.8724 &   selected: type_median_encoding
# [4/270]Elapsed 5m 0s (remain 333m 26s) Score: 46.8724 -> 46.6551 &   selected: fuel_median_odometer_encoding_diff
# [5/270]Elapsed 6m 21s (remain 337m 21s) Score: 46.6551 -> 46.1967 &   selected: drive_median_odometer_encoding
# [6/270]Elapsed 7m 49s (remain 344m 18s) Score: 46.1967 -> 45.7932 &   selected: type_median_odometer_encoding
# [7/270]Elapsed 9m 14s (remain 347m 23s) Score: 45.7932 -> 45.7415 &   selected: size_min_odometer_encoding
# [8/270]Elapsed 10m 37s (remain 348m 4s) Score: 45.7415 -> 45.7337 &   selected: size_category
# [9/270]Elapsed 12m 15s (remain 355m 22s) Score: 45.7337 -> 45.9527 & unselected: fuel_min_odometer_encoding
# [10/270]Elapsed 13m 43s (remain 357m 2s) Score: 45.7337 -> 45.0596 &   selected: condition_median_odometer_encoding
# [11/270]Elapsed 15m 9s (remain 356m 45s) Score: 45.0596 -> 44.9960 &   selected: drive_mean_elapsed_years_encoding_diff
# [12/270]Elapsed 16m 38s (remain 357m 57s) Score: 44.9960 -> 44.7673 &   selected: manufacturer_std_encoding
# [13/270]Elapsed 18m 8s (remain 358m 29s) Score: 44.7673 -> 44.5892 &   selected: condition_category
# [14/270]Elapsed 19m 34s (remain 357m 49s) Score: 44.5892 -> 44.6407 & unselected: type_mean_encoding
# [15/270]Elapsed 20m 59s (remain 356m 53s) Score: 44.5892 -> 44.7071 & unselected: elapsed_years*odometer
# [16/270]Elapsed 22m 34s (remain 358m 26s) Score: 44.5892 -> 44.6425 & unselected: transmission_median_elapsed_years_encoding
# [17/270]Elapsed 24m 11s (remain 359m 57s) Score: 44.5892 -> 44.6176 & unselected: transmission_max_odometer_encoding
# [18/270]Elapsed 25m 35s (remain 358m 14s) Score: 44.5892 -> 44.4695 &   selected: paint_color_mean_elapsed_years_encoding
# [19/270]Elapsed 27m 1s (remain 356m 56s) Score: 44.4695 -> 44.4754 & unselected: paint_color_min_encoding
# [20/270]Elapsed 28m 28s (remain 355m 58s) Score: 44.4695 -> 44.5186 & unselected: region_median_odometer_encoding
# [21/270]Elapsed 29m 56s (remain 354m 55s) Score: 44.4695 -> 44.4423 &   selected: drive_category
# [22/270]Elapsed 31m 33s (remain 355m 42s) Score: 44.4423 -> 44.4707 & unselected: condition_max_odometer_encoding
# [23/270]Elapsed 33m 7s (remain 355m 39s) Score: 44.4423 -> 44.5746 & unselected: region_min_elapsed_years_encoding
# [24/270]Elapsed 34m 41s (remain 355m 38s) Score: 44.4423 -> 44.3973 &   selected: size_min_encoding
# [25/270]Elapsed 36m 10s (remain 354m 30s) Score: 44.3973 -> 44.4412 & unselected: state_mean_encoding
# [26/270]Elapsed 37m 41s (remain 353m 42s) Score: 44.3973 -> 44.4212 & unselected: condition_mean_odometer_encoding
# [27/270]Elapsed 39m 15s (remain 353m 23s) Score: 44.3973 -> 44.4544 & unselected: fuel_mean_elapsed_years_encoding_diff
# [28/270]Elapsed 40m 45s (remain 352m 12s) Score: 44.3973 -> 44.4430 & unselected: condition_mean_encoding
# [29/270]Elapsed 42m 27s (remain 352m 49s) Score: 44.3973 -> 44.4743 & unselected: region_max_encoding
# [30/270]Elapsed 43m 58s (remain 351m 44s) Score: 44.3973 -> 44.4450 & unselected: condition_mean_elapsed_years_encoding
# [31/270]Elapsed 45m 28s (remain 350m 33s) Score: 44.3973 -> 44.4388 & unselected: sqrt_elapsed_years*log_odometer
# [32/270]Elapsed 47m 8s (remain 350m 37s) Score: 44.3973 -> 44.4567 & unselected: paint_color_max_odometer_encoding
# [33/270]Elapsed 49m 8s (remain 352m 55s) Score: 44.3973 -> 44.3719 &   selected: title_status_max_odometer_encoding
# [34/270]Elapsed 50m 52s (remain 353m 8s) Score: 44.3719 -> 44.4941 & unselected: cylinders_mean_elapsed_years_encoding_diff
# [35/270]Elapsed 52m 41s (remain 353m 46s) Score: 44.3719 -> 44.4422 & unselected: manufacturer_mean_odometer_encoding
# [36/270]Elapsed 54m 25s (remain 353m 47s) Score: 44.3719 -> 44.3931 & unselected: transmission_std_odometer_encoding
# [37/270]Elapsed 56m 10s (remain 353m 43s) Score: 44.3719 -> 44.3961 & unselected: paint_color_count_encoding
# [38/270]Elapsed 57m 52s (remain 353m 22s) Score: 44.3719 -> 44.3499 &   selected: drive_std_encoding
# [39/270]Elapsed 59m 36s (remain 353m 1s) Score: 44.3499 -> 44.4254 & unselected: fuel_max_elapsed_years_encoding
# [40/270]Elapsed 61m 27s (remain 353m 24s) Score: 44.3499 -> 44.4550 & unselected: size_std_odometer_encoding
# [41/270]Elapsed 63m 15s (remain 353m 19s) Score: 44.3499 -> 44.4202 & unselected: fuel_category
# [42/270]Elapsed 64m 57s (remain 352m 36s) Score: 44.3499 -> 44.4315 & unselected: size_max_encoding
# [43/270]Elapsed 66m 44s (remain 352m 21s) Score: 44.3499 -> 44.4527 & unselected: fuel_std_encoding
# [44/270]Elapsed 68m 25s (remain 351m 26s) Score: 44.3499 -> 44.4230 & unselected: region_count_encoding
# [45/270]Elapsed 70m 7s (remain 350m 39s) Score: 44.3499 -> 44.4607 & unselected: region_min_encoding
# [46/270]Elapsed 71m 45s (remain 349m 24s) Score: 44.3499 -> 44.4559 & unselected: region_mean_encoding
# [47/270]Elapsed 73m 28s (remain 348m 35s) Score: 44.3499 -> 44.4614 & unselected: type_std_elapsed_years_encoding
# [48/270]Elapsed 75m 17s (remain 348m 14s) Score: 44.3499 -> 44.4096 & unselected: size_mean_elapsed_years_encoding
# [49/270]Elapsed 77m 3s (remain 347m 34s) Score: 44.3499 -> 44.4324 & unselected: title_status_min_encoding
# [50/270]Elapsed 78m 51s (remain 347m 0s) Score: 44.3499 -> 44.4067 & unselected: state_median_elapsed_years_encoding
# [51/270]Elapsed 80m 40s (remain 346m 25s) Score: 44.3499 -> 44.3965 & unselected: title_status_count_encoding
# [52/270]Elapsed 82m 21s (remain 345m 15s) Score: 44.3499 -> 44.3949 & unselected: elapsed_years*sqrt_odometer
# [53/270]Elapsed 84m 12s (remain 344m 44s) Score: 44.3499 -> 44.4102 & unselected: transmission_count_encoding
# [54/270]Elapsed 85m 57s (remain 343m 50s) Score: 44.3499 -> 44.4786 & unselected: region_latitude
# [55/270]Elapsed 87m 43s (remain 342m 56s) Score: 44.3499 -> 44.4104 & unselected: manufacturer_median_odometer_encoding
# [56/270]Elapsed 89m 25s (remain 341m 45s) Score: 44.3499 -> 44.4507 & unselected: type_min_odometer_encoding
# [57/270]Elapsed 91m 9s (remain 340m 37s) Score: 44.3499 -> 44.4464 & unselected: region_longitude
# [58/270]Elapsed 92m 54s (remain 339m 37s) Score: 44.3499 -> 44.3617 & unselected: paint_color_median_elapsed_years_encoding
# [59/270]Elapsed 94m 43s (remain 338m 44s) Score: 44.3499 -> 44.3890 & unselected: paint_color_max_elapsed_years_encoding
# [60/270]Elapsed 96m 30s (remain 337m 48s) Score: 44.3499 -> 44.4476 & unselected: manufacturer_mean_odometer_encoding_diff
# [61/270]Elapsed 98m 12s (remain 336m 28s) Score: 44.3499 -> 44.3838 & unselected: cylinders_mean_elapsed_years_encoding
# [62/270]Elapsed 99m 57s (remain 335m 19s) Score: 44.3499 -> 44.4636 & unselected: sqrt_elapsed_years*sqrt_odometer
# [63/270]Elapsed 101m 41s (remain 334m 8s) Score: 44.3499 -> 44.4316 & unselected: cylinders_max_odometer_encoding
# [64/270]Elapsed 103m 38s (remain 333m 35s) Score: 44.3499 -> 44.4462 & unselected: drive_mean_elapsed_years_encoding
# [65/270]Elapsed 105m 26s (remain 332m 33s) Score: 44.3499 -> 44.3670 & unselected: condition_max_encoding
# [66/270]Elapsed 107m 22s (remain 331m 53s) Score: 44.3499 -> 44.4462 & unselected: drive_count_encoding
# [67/270]Elapsed 109m 13s (remain 330m 57s) Score: 44.3499 -> 44.4008 & unselected: condition_max_elapsed_years_encoding
# [68/270]Elapsed 110m 55s (remain 329m 30s) Score: 44.3499 -> 44.4351 & unselected: condition_median_elapsed_years_encoding_diff
# [69/270]Elapsed 112m 41s (remain 328m 16s) Score: 44.3499 -> 44.3893 & unselected: title_status_max_encoding
# [70/270]Elapsed 114m 28s (remain 327m 5s) Score: 44.3499 -> 44.3907 & unselected: manufacturer_min_encoding
# [71/270]Elapsed 116m 10s (remain 325m 38s) Score: 44.3499 -> 44.3660 & unselected: sqrt_elapsed_years*odometer
# [72/270]Elapsed 117m 55s (remain 324m 17s) Score: 44.3499 -> 44.4817 & unselected: type_count_encoding
# [73/270]Elapsed 119m 37s (remain 322m 49s) Score: 44.3499 -> 44.4436 & unselected: manufacturer_count_encoding
# [74/270]Elapsed 121m 23s (remain 321m 30s) Score: 44.3499 -> 44.3737 & unselected: condition_std_elapsed_years_encoding
# [75/270]Elapsed 123m 14s (remain 320m 26s) Score: 44.3499 -> 44.4285 & unselected: condition_min_elapsed_years_encoding
# [76/270]Elapsed 125m 7s (remain 319m 24s) Score: 44.3499 -> 44.4442 & unselected: title_status_mean_odometer_encoding_diff
# [77/270]Elapsed 126m 52s (remain 318m 0s) Score: 44.3499 -> 44.4431 & unselected: size_median_elapsed_years_encoding
# [78/270]Elapsed 128m 38s (remain 316m 39s) Score: 44.3499 -> 44.4064 & unselected: state_max_odometer_encoding
# [79/270]Elapsed 130m 26s (remain 315m 21s) Score: 44.3499 -> 44.3876 & unselected: manufacturer_median_encoding
# [80/270]Elapsed 132m 13s (remain 314m 1s) Score: 44.3499 -> 44.4336 & unselected: size_median_odometer_encoding
# [81/270]Elapsed 133m 55s (remain 312m 29s) Score: 44.3499 -> 44.4318 & unselected: title_status_mean_elapsed_years_encoding_diff
# [82/270]Elapsed 135m 37s (remain 310m 56s) Score: 44.3499 -> 44.3951 & unselected: log_odometer
# [83/270]Elapsed 137m 27s (remain 309m 42s) Score: 44.3499 -> 44.3909 & unselected: drive_max_odometer_encoding
# [84/270]Elapsed 139m 20s (remain 308m 31s) Score: 44.3499 -> 44.3888 & unselected: state_mean_elapsed_years_encoding
# [85/270]Elapsed 141m 12s (remain 307m 19s) Score: 44.3499 -> 44.4443 & unselected: fuel_mean_odometer_encoding_diff
# [86/270]Elapsed 143m 2s (remain 306m 2s) Score: 44.3499 -> 44.3593 & unselected: log_elapsed_years*log_odometer
# [87/270]Elapsed 144m 45s (remain 304m 29s) Score: 44.3499 -> 44.4255 & unselected: paint_color_min_odometer_encoding
# [88/270]Elapsed 146m 30s (remain 303m 1s) Score: 44.3499 -> 44.3602 & unselected: condition_mean_odometer_encoding_diff
# [89/270]Elapsed 148m 20s (remain 301m 40s) Score: 44.3499 -> 44.4297 & unselected: paint_color_median_elapsed_years_encoding_diff
# [90/270]Elapsed 150m 9s (remain 300m 18s) Score: 44.3499 -> 44.3591 & unselected: elapsed_years*log_odometer
# [91/270]Elapsed 151m 59s (remain 298m 59s) Score: 44.3499 -> 44.3423 &   selected: paint_color_std_encoding
# [92/270]Elapsed 153m 45s (remain 297m 28s) Score: 44.3423 -> 44.3756 & unselected: type_mean_odometer_encoding_diff
# [93/270]Elapsed 155m 33s (remain 296m 4s) Score: 44.3423 -> 44.3563 & unselected: manufacturer_min_elapsed_years_encoding
# [94/270]Elapsed 157m 23s (remain 294m 40s) Score: 44.3423 -> 44.3686 & unselected: cylinders_median_odometer_encoding
# [95/270]Elapsed 159m 9s (remain 293m 11s) Score: 44.3423 -> 44.3236 &   selected: cylinders_mean_odometer_encoding
# [96/270]Elapsed 160m 56s (remain 291m 41s) Score: 44.3236 -> 44.3360 & unselected: transmission_median_encoding
# [97/270]Elapsed 162m 42s (remain 290m 10s) Score: 44.3236 -> 44.3354 & unselected: type_std_odometer_encoding
# [98/270]Elapsed 164m 26s (remain 288m 36s) Score: 44.3236 -> 44.3758 & unselected: state_median_odometer_encoding_diff
# [99/270]Elapsed 166m 14s (remain 287m 8s) Score: 44.3236 -> 44.3380 & unselected: cylinders_max_elapsed_years_encoding
# [100/270]Elapsed 167m 58s (remain 285m 32s) Score: 44.3236 -> 44.4152 & unselected: type_max_encoding
# [101/270]Elapsed 169m 40s (remain 283m 54s) Score: 44.3236 -> 44.3520 & unselected: cylinders_max_encoding
# [102/270]Elapsed 171m 23s (remain 282m 17s) Score: 44.3236 -> 44.3673 & unselected: condition_min_odometer_encoding
# [103/270]Elapsed 173m 10s (remain 280m 47s) Score: 44.3236 -> 44.3221 &   selected: title_status_max_elapsed_years_encoding
# [104/270]Elapsed 174m 56s (remain 279m 14s) Score: 44.3221 -> 44.2962 &   selected: title_status_min_odometer_encoding
# [105/270]Elapsed 176m 39s (remain 277m 36s) Score: 44.2962 -> 44.2813 &   selected: title_status_mean_encoding
# [106/270]Elapsed 178m 19s (remain 275m 54s) Score: 44.2813 -> 44.3415 & unselected: region_min_odometer_encoding
# [107/270]Elapsed 180m 4s (remain 274m 18s) Score: 44.2813 -> 44.3622 & unselected: paint_color_mean_encoding
# [108/270]Elapsed 181m 57s (remain 272m 56s) Score: 44.2813 -> 44.3797 & unselected: region_mean_elapsed_years_encoding_diff
# [109/270]Elapsed 183m 55s (remain 271m 39s) Score: 44.2813 -> 44.3335 & unselected: sqrt_odometer
# [110/270]Elapsed 185m 46s (remain 270m 13s) Score: 44.2813 -> 44.3798 & unselected: state_min_elapsed_years_encoding
# [111/270]Elapsed 187m 35s (remain 268m 42s) Score: 44.2813 -> 44.3489 & unselected: fuel_median_encoding
# [112/270]Elapsed 189m 27s (remain 267m 15s) Score: 44.2813 -> 44.3391 & unselected: size_std_elapsed_years_encoding
# [113/270]Elapsed 191m 14s (remain 265m 41s) Score: 44.2813 -> 44.3233 & unselected: manufacturer_max_encoding
# [114/270]Elapsed 192m 56s (remain 264m 1s) Score: 44.2813 -> 44.4210 & unselected: fuel_max_encoding
# [115/270]Elapsed 194m 38s (remain 262m 20s) Score: 44.2813 -> 44.3701 & unselected: drive_median_elapsed_years_encoding_diff
# [116/270]Elapsed 196m 20s (remain 260m 39s) Score: 44.2813 -> 44.3610 & unselected: cylinders_median_odometer_encoding_diff
# [117/270]Elapsed 198m 8s (remain 259m 6s) Score: 44.2813 -> 44.3433 & unselected: manufacturer_mean_encoding
# [118/270]Elapsed 199m 53s (remain 257m 28s) Score: 44.2813 -> 44.3328 & unselected: drive_mean_odometer_encoding
# [119/270]Elapsed 201m 34s (remain 255m 47s) Score: 44.2813 -> 44.2943 & unselected: paint_color_category
# [120/270]Elapsed 203m 31s (remain 254m 24s) Score: 44.2813 -> 44.2840 & unselected: log_elapsed_years*odometer
# [121/270]Elapsed 205m 18s (remain 252m 49s) Score: 44.2813 -> 44.3640 & unselected: manufacturer_category
# [122/270]Elapsed 207m 4s (remain 251m 12s) Score: 44.2813 -> 44.4040 & unselected: cylinders_mean_encoding
# [123/270]Elapsed 209m 1s (remain 249m 48s) Score: 44.2813 -> 44.3394 & unselected: condition_std_encoding
# [124/270]Elapsed 210m 48s (remain 248m 12s) Score: 44.2813 -> 44.3652 & unselected: size_median_encoding
# [125/270]Elapsed 212m 35s (remain 246m 36s) Score: 44.2813 -> 44.3057 & unselected: size_median_elapsed_years_encoding_diff
# [126/270]Elapsed 214m 16s (remain 244m 53s) Score: 44.2813 -> 44.3688 & unselected: title_status_mean_odometer_encoding
# [127/270]Elapsed 216m 0s (remain 243m 13s) Score: 44.2813 -> 44.3465 & unselected: fuel_median_odometer_encoding
# [128/270]Elapsed 217m 45s (remain 241m 34s) Score: 44.2813 -> 44.3734 & unselected: state_min_odometer_encoding
# [129/270]Elapsed 219m 34s (remain 240m 0s) Score: 44.2813 -> 44.3576 & unselected: fuel_mean_encoding
# [130/270]Elapsed 221m 30s (remain 238m 32s) Score: 44.2813 -> 44.3418 & unselected: region_std_encoding
# [131/270]Elapsed 223m 12s (remain 236m 50s) Score: 44.2813 -> 44.3981 & unselected: transmission_median_odometer_encoding
# [132/270]Elapsed 225m 0s (remain 235m 14s) Score: 44.2813 -> 44.3820 & unselected: cylinders_min_odometer_encoding
# [133/270]Elapsed 226m 46s (remain 233m 35s) Score: 44.2813 -> 44.3465 & unselected: fuel_mean_odometer_encoding
# [134/270]Elapsed 228m 39s (remain 232m 3s) Score: 44.2813 -> 44.3466 & unselected: drive_mean_encoding
# [135/270]Elapsed 230m 26s (remain 230m 26s) Score: 44.2813 -> 44.3847 & unselected: size_max_elapsed_years_encoding
# [136/270]Elapsed 232m 19s (remain 228m 54s) Score: 44.2813 -> 44.3750 & unselected: elapsed_years
# [137/270]Elapsed 234m 1s (remain 227m 11s) Score: 44.2813 -> 44.3602 & unselected: state_max_encoding
# [138/270]Elapsed 235m 49s (remain 225m 34s) Score: 44.2813 -> 44.3755 & unselected: paint_color_max_encoding
# [139/270]Elapsed 237m 32s (remain 223m 51s) Score: 44.2813 -> 44.3981 & unselected: transmission_mean_odometer_encoding
# [140/270]Elapsed 239m 21s (remain 222m 15s) Score: 44.2813 -> 44.3417 & unselected: drive_min_encoding
# [141/270]Elapsed 241m 11s (remain 220m 39s) Score: 44.2813 -> 44.3750 & unselected: sqrt_elapsed_years
# [142/270]Elapsed 242m 59s (remain 219m 2s) Score: 44.2813 -> 44.3082 & unselected: cylinders_min_elapsed_years_encoding
# [143/270]Elapsed 244m 43s (remain 217m 20s) Score: 44.2813 -> 44.3383 & unselected: paint_color_std_odometer_encoding
# [144/270]Elapsed 246m 26s (remain 215m 38s) Score: 44.2813 -> 44.3243 & unselected: condition_median_odometer_encoding_diff
# [145/270]Elapsed 248m 18s (remain 214m 3s) Score: 44.2813 -> 44.3608 & unselected: title_status_median_encoding
# [146/270]Elapsed 250m 9s (remain 212m 27s) Score: 44.2813 -> 44.3882 & unselected: size_mean_encoding
# [147/270]Elapsed 251m 56s (remain 210m 48s) Score: 44.2813 -> 44.3772 & unselected: transmission_mean_elapsed_years_encoding_diff
# [148/270]Elapsed 253m 46s (remain 209m 11s) Score: 44.2813 -> 44.3661 & unselected: fuel_min_elapsed_years_encoding
# [149/270]Elapsed 255m 31s (remain 207m 30s) Score: 44.2813 -> 44.3418 & unselected: transmission_median_elapsed_years_encoding_diff
# [150/270]Elapsed 257m 21s (remain 205m 53s) Score: 44.2813 -> 44.3387 & unselected: cylinders_category
# [151/270]Elapsed 259m 8s (remain 204m 13s) Score: 44.2813 -> 44.3994 & unselected: type_mean_elapsed_years_encoding_diff
# [152/270]Elapsed 260m 59s (remain 202m 37s) Score: 44.2813 -> 44.3405 & unselected: type_median_elapsed_years_encoding
# [153/270]Elapsed 262m 53s (remain 201m 2s) Score: 44.2813 -> 44.3383 & unselected: region_max_odometer_encoding
# [154/270]Elapsed 264m 38s (remain 199m 20s) Score: 44.2813 -> 44.3584 & unselected: size_mean_odometer_encoding_diff
# [155/270]Elapsed 266m 23s (remain 197m 38s) Score: 44.2813 -> 44.3650 & unselected: manufacturer_median_elapsed_years_encoding
# [156/270]Elapsed 268m 21s (remain 196m 6s) Score: 44.2813 -> 44.3550 & unselected: cylinders_std_encoding
# [157/270]Elapsed 270m 20s (remain 194m 34s) Score: 44.2813 -> 44.3139 & unselected: cylinders_median_elapsed_years_encoding
# [158/270]Elapsed 272m 13s (remain 192m 58s) Score: 44.2813 -> 44.4069 & unselected: transmission_mean_encoding
# [159/270]Elapsed 274m 7s (remain 191m 22s) Score: 44.2813 -> 44.3750 & unselected: log_elapsed_years
# [160/270]Elapsed 275m 52s (remain 189m 40s) Score: 44.2813 -> 44.3608 & unselected: fuel_std_odometer_encoding
# [161/270]Elapsed 277m 39s (remain 187m 58s) Score: 44.2813 -> 44.3470 & unselected: type_min_encoding
# [162/270]Elapsed 279m 28s (remain 186m 19s) Score: 44.2813 -> 44.3806 & unselected: state_max_elapsed_years_encoding
# [163/270]Elapsed 281m 18s (remain 184m 40s) Score: 44.2813 -> 44.3573 & unselected: cylinders_min_encoding
# [164/270]Elapsed 283m 8s (remain 183m 0s) Score: 44.2813 -> 44.3785 & unselected: manufacturer_std_odometer_encoding
# [165/270]Elapsed 285m 1s (remain 181m 22s) Score: 44.2813 -> 44.3414 & unselected: type_category
# [166/270]Elapsed 286m 59s (remain 179m 47s) Score: 44.2813 -> 44.3345 & unselected: title_status_std_odometer_encoding
# [167/270]Elapsed 289m 10s (remain 178m 21s) Score: 44.2813 -> 44.3734 & unselected: log_elapsed_years*sqrt_odometer
# [168/270]Elapsed 291m 4s (remain 176m 43s) Score: 44.2813 -> 44.4035 & unselected: paint_color_mean_elapsed_years_encoding_diff
# [169/270]Elapsed 292m 53s (remain 175m 2s) Score: 44.2813 -> 44.3620 & unselected: region_median_odometer_encoding_diff
# [170/270]Elapsed 294m 40s (remain 173m 20s) Score: 44.2813 -> 44.3801 & unselected: cylinders_std_elapsed_years_encoding
# [171/270]Elapsed 296m 26s (remain 171m 37s) Score: 44.2813 -> 44.3596 & unselected: fuel_max_odometer_encoding
# [172/270]Elapsed 298m 30s (remain 170m 4s) Score: 44.2813 -> 44.6098 & unselected: region_category
# [173/270]Elapsed 300m 21s (remain 168m 24s) Score: 44.2813 -> 44.3466 & unselected: drive_median_encoding
# [174/270]Elapsed 302m 17s (remain 166m 46s) Score: 44.2813 -> 44.3693 & unselected: manufacturer_max_elapsed_years_encoding
# [175/270]Elapsed 304m 8s (remain 165m 6s) Score: 44.2813 -> 44.3714 & unselected: type_max_elapsed_years_encoding
# [176/270]Elapsed 305m 54s (remain 163m 22s) Score: 44.2813 -> 44.3792 & unselected: state_median_encoding
# [177/270]Elapsed 307m 39s (remain 161m 38s) Score: 44.2813 -> 44.3291 & unselected: state_mean_odometer_encoding_diff
# [178/270]Elapsed 309m 32s (remain 159m 59s) Score: 44.2813 -> 44.3335 & unselected: drive_median_elapsed_years_encoding
# [179/270]Elapsed 311m 12s (remain 158m 12s) Score: 44.2813 -> 44.3924 & unselected: transmission_min_odometer_encoding
# [180/270]Elapsed 312m 54s (remain 156m 27s) Score: 44.2813 -> 44.4660 & unselected: state_category
# [181/270]Elapsed 314m 35s (remain 154m 41s) Score: 44.2813 -> 44.3466 & unselected: drive_max_encoding
# [182/270]Elapsed 316m 21s (remain 152m 57s) Score: 44.2813 -> 44.3545 & unselected: manufacturer_mean_elapsed_years_encoding_diff
# [183/270]Elapsed 318m 9s (remain 151m 15s) Score: 44.2813 -> 44.3239 & unselected: type_mean_odometer_encoding
# [184/270]Elapsed 319m 47s (remain 149m 28s) Score: 44.2813 -> 44.3748 & unselected: transmission_min_encoding
# [185/270]Elapsed 321m 33s (remain 147m 44s) Score: 44.2813 -> 44.3957 & unselected: state_std_encoding
# [186/270]Elapsed 323m 38s (remain 146m 9s) Score: 44.2813 -> 44.3499 & unselected: drive_min_odometer_encoding
# [187/270]Elapsed 325m 27s (remain 144m 27s) Score: 44.2813 -> 44.3510 & unselected: title_status_median_odometer_encoding
# [188/270]Elapsed 327m 18s (remain 142m 45s) Score: 44.2813 -> 44.4215 & unselected: transmission_max_elapsed_years_encoding
# [189/270]Elapsed 329m 5s (remain 141m 2s) Score: 44.2813 -> 44.3780 & unselected: region_mean_odometer_encoding
# [190/270]Elapsed 330m 54s (remain 139m 19s) Score: 44.2813 -> 44.3523 & unselected: title_status_std_elapsed_years_encoding
# [191/270]Elapsed 332m 37s (remain 137m 34s) Score: 44.2813 -> 44.3666 & unselected: manufacturer_std_elapsed_years_encoding
# [192/270]Elapsed 334m 20s (remain 135m 49s) Score: 44.2813 -> 44.4539 & unselected: paint_color_median_odometer_encoding_diff
# [193/270]Elapsed 336m 8s (remain 134m 6s) Score: 44.2813 -> 44.3317 & unselected: drive_std_odometer_encoding
# [194/270]Elapsed 337m 57s (remain 132m 23s) Score: 44.2813 -> 44.4025 & unselected: transmission_median_odometer_encoding_diff
# [195/270]Elapsed 339m 40s (remain 130m 38s) Score: 44.2813 -> 44.3782 & unselected: state_latitude
# [196/270]Elapsed 341m 22s (remain 128m 53s) Score: 44.2813 -> 44.3705 & unselected: state_median_elapsed_years_encoding_diff
# [197/270]Elapsed 343m 5s (remain 127m 8s) Score: 44.2813 -> 44.3328 & unselected: size_median_odometer_encoding_diff
# [198/270]Elapsed 344m 48s (remain 125m 23s) Score: 44.2813 -> 44.3867 & unselected: fuel_min_encoding
# [199/270]Elapsed 346m 33s (remain 123m 38s) Score: 44.2813 -> 44.3420 & unselected: title_status_mean_elapsed_years_encoding
# [200/270]Elapsed 348m 33s (remain 121m 59s) Score: 44.2813 -> 44.3731 & unselected: state_count_encoding
# [201/270]Elapsed 350m 17s (remain 120m 14s) Score: 44.2813 -> 44.3584 & unselected: size_max_odometer_encoding
# [202/270]Elapsed 352m 0s (remain 118m 29s) Score: 44.2813 -> 44.3770 & unselected: size_mean_elapsed_years_encoding_diff
# [203/270]Elapsed 353m 50s (remain 116m 46s) Score: 44.2813 -> 44.4063 & unselected: cylinders_median_elapsed_years_encoding_diff
# [204/270]Elapsed 355m 30s (remain 115m 1s) Score: 44.2813 -> 44.3230 & unselected: condition_std_odometer_encoding
# [205/270]Elapsed 357m 18s (remain 113m 17s) Score: 44.2813 -> 44.3623 & unselected: state_longitude
# [206/270]Elapsed 359m 3s (remain 111m 33s) Score: 44.2813 -> 44.3681 & unselected: paint_color_min_elapsed_years_encoding
# [207/270]Elapsed 360m 44s (remain 109m 47s) Score: 44.2813 -> 44.3469 & unselected: title_status_std_encoding
# [208/270]Elapsed 362m 41s (remain 108m 6s) Score: 44.2813 -> 44.3552 & unselected: transmission_min_elapsed_years_encoding
# [209/270]Elapsed 364m 28s (remain 106m 22s) Score: 44.2813 -> 44.3640 & unselected: condition_min_encoding
# [210/270]Elapsed 366m 11s (remain 104m 37s) Score: 44.2813 -> 44.3775 & unselected: paint_color_std_elapsed_years_encoding
# [211/270]Elapsed 367m 49s (remain 102m 51s) Score: 44.2813 -> 44.3885 & unselected: transmission_std_encoding
# [212/270]Elapsed 369m 39s (remain 101m 7s) Score: 44.2813 -> 44.3483 & unselected: title_status_median_elapsed_years_encoding_diff
# [213/270]Elapsed 371m 32s (remain 99m 25s) Score: 44.2813 -> 44.3172 & unselected: drive_min_elapsed_years_encoding
# [214/270]Elapsed 373m 19s (remain 97m 41s) Score: 44.2813 -> 44.3424 & unselected: condition_median_encoding
# [215/270]Elapsed 375m 13s (remain 95m 59s) Score: 44.2813 -> 44.3474 & unselected: region_median_elapsed_years_encoding
# [216/270]Elapsed 377m 5s (remain 94m 16s) Score: 44.2813 -> 44.3609 & unselected: title_status_category
# [217/270]Elapsed 378m 52s (remain 92m 32s) Score: 44.2813 -> 44.3422 & unselected: cylinders_median_encoding
# [218/270]Elapsed 380m 39s (remain 90m 47s) Score: 44.2813 -> 44.3548 & unselected: size_mean_odometer_encoding
# [219/270]Elapsed 382m 27s (remain 89m 3s) Score: 44.2813 -> 44.4000 & unselected: paint_color_median_odometer_encoding
# [220/270]Elapsed 384m 16s (remain 87m 20s) Score: 44.2813 -> 44.3639 & unselected: fuel_median_elapsed_years_encoding_diff
# [221/270]Elapsed 385m 55s (remain 85m 34s) Score: 44.2813 -> 44.3633 & unselected: fuel_median_elapsed_years_encoding
# [222/270]Elapsed 387m 42s (remain 83m 49s) Score: 44.2813 -> 44.3565 & unselected: state_std_elapsed_years_encoding
# [223/270]Elapsed 389m 31s (remain 82m 5s) Score: 44.2813 -> 44.3154 & unselected: paint_color_mean_odometer_encoding
# [224/270]Elapsed 391m 25s (remain 80m 22s) Score: 44.2813 -> 44.3578 & unselected: transmission_mean_odometer_encoding_diff
# [225/270]Elapsed 393m 19s (remain 78m 39s) Score: 44.2813 -> 44.3328 & unselected: drive_std_elapsed_years_encoding
# [226/270]Elapsed 395m 5s (remain 76m 55s) Score: 44.2813 -> 44.3744 & unselected: manufacturer_median_odometer_encoding_diff
# [227/270]Elapsed 396m 49s (remain 75m 10s) Score: 44.2813 -> 44.3858 & unselected: state_std_odometer_encoding
# [228/270]Elapsed 398m 45s (remain 73m 27s) Score: 44.2813 -> 44.3172 & unselected: condition_median_elapsed_years_encoding
# [229/270]Elapsed 400m 28s (remain 71m 42s) Score: 44.2813 -> 44.3467 & unselected: title_status_median_elapsed_years_encoding
# [230/270]Elapsed 402m 13s (remain 69m 57s) Score: 44.2813 -> 44.3560 & unselected: fuel_mean_elapsed_years_encoding
# [231/270]Elapsed 404m 10s (remain 68m 14s) Score: 44.2813 -> 44.3505 & unselected: type_mean_elapsed_years_encoding
# [232/270]Elapsed 405m 53s (remain 66m 28s) Score: 44.2813 -> 44.4052 & unselected: manufacturer_mean_elapsed_years_encoding
# [233/270]Elapsed 407m 48s (remain 64m 45s) Score: 44.2813 -> 44.3413 & unselected: drive_median_odometer_encoding_diff
# [234/270]Elapsed 409m 45s (remain 63m 2s) Score: 44.2813 -> 44.3709 & unselected: transmission_mean_elapsed_years_encoding
# [235/270]Elapsed 411m 30s (remain 61m 17s) Score: 44.2813 -> 44.2966 & unselected: condition_mean_elapsed_years_encoding_diff
# [236/270]Elapsed 413m 27s (remain 59m 33s) Score: 44.2813 -> 44.3341 & unselected: title_status_median_odometer_encoding_diff
# [237/270]Elapsed 415m 18s (remain 57m 49s) Score: 44.2813 -> 44.3374 & unselected: state_mean_elapsed_years_encoding_diff
# [238/270]Elapsed 417m 15s (remain 56m 6s) Score: 44.2813 -> 44.3718 & unselected: manufacturer_median_elapsed_years_encoding_diff
# [239/270]Elapsed 419m 4s (remain 54m 21s) Score: 44.2813 -> 44.3255 & unselected: paint_color_median_encoding
# [240/270]Elapsed 420m 48s (remain 52m 36s) Score: 44.2813 -> 44.3601 & unselected: size_count_encoding
# [241/270]Elapsed 422m 45s (remain 50m 52s) Score: 44.2813 -> 44.3902 & unselected: region_mean_odometer_encoding_diff
# [242/270]Elapsed 424m 43s (remain 49m 8s) Score: 44.2813 -> 44.3347 & unselected: type_min_elapsed_years_encoding
# [243/270]Elapsed 426m 36s (remain 47m 24s) Score: 44.2813 -> 44.3882 & unselected: size_std_encoding
# [244/270]Elapsed 428m 53s (remain 45m 42s) Score: 44.2813 -> 44.3908 & unselected: region_std_odometer_encoding
# [245/270]Elapsed 430m 37s (remain 43m 56s) Score: 44.2813 -> 44.3216 & unselected: condition_count_encoding
# [246/270]Elapsed 432m 18s (remain 42m 10s) Score: 44.2813 -> 44.3885 & unselected: transmission_max_encoding
# [247/270]Elapsed 434m 12s (remain 40m 25s) Score: 44.2813 -> 44.3614 & unselected: type_max_odometer_encoding
# [248/270]Elapsed 435m 54s (remain 38m 40s) Score: 44.2813 -> 44.3879 & unselected: transmission_category
# [249/270]Elapsed 437m 42s (remain 36m 54s) Score: 44.2813 -> 44.3543 & unselected: region_max_elapsed_years_encoding
# [250/270]Elapsed 439m 34s (remain 35m 9s) Score: 44.2813 -> 44.3980 & unselected: type_median_elapsed_years_encoding_diff
# [251/270]Elapsed 441m 17s (remain 33m 24s) Score: 44.2813 -> 44.3590 & unselected: title_status_min_elapsed_years_encoding
# [252/270]Elapsed 443m 13s (remain 31m 39s) Score: 44.2813 -> 44.3709 & unselected: transmission_std_elapsed_years_encoding
# [253/270]Elapsed 445m 14s (remain 29m 55s) Score: 44.2813 -> 44.3405 & unselected: cylinders_count_encoding
# [254/270]Elapsed 447m 11s (remain 28m 10s) Score: 44.2813 -> 44.3478 & unselected: manufacturer_min_odometer_encoding
# [255/270]Elapsed 448m 59s (remain 26m 24s) Score: 44.2813 -> 44.3724 & unselected: cylinders_std_odometer_encoding
# [256/270]Elapsed 450m 45s (remain 24m 39s) Score: 44.2813 -> 44.3765 & unselected: cylinders_mean_odometer_encoding_diff
# [257/270]Elapsed 452m 32s (remain 22m 53s) Score: 44.2813 -> 44.3810 & unselected: fuel_count_encoding
# [258/270]Elapsed 454m 14s (remain 21m 7s) Score: 44.2813 -> 44.3747 & unselected: size_min_elapsed_years_encoding
# [259/270]Elapsed 455m 58s (remain 19m 21s) Score: 44.2813 -> 44.3185 & unselected: region_median_elapsed_years_encoding_diff
# [260/270]Elapsed 457m 49s (remain 17m 36s) Score: 44.2813 -> 44.3368 & unselected: type_std_encoding
# [261/270]Elapsed 459m 48s (remain 15m 51s) Score: 44.2813 -> 44.3340 & unselected: drive_mean_odometer_encoding_diff
# [262/270]Elapsed 461m 33s (remain 14m 5s) Score: 44.2813 -> 44.4212 & unselected: state_median_odometer_encoding
# [263/270]Elapsed 463m 31s (remain 12m 20s) Score: 44.2813 -> 44.3579 & unselected: manufacturer_max_odometer_encoding
# [264/270]Elapsed 465m 20s (remain 10m 34s) Score: 44.2813 -> 44.4108 & unselected: type_median_odometer_encoding_diff
# [265/270]Elapsed 467m 5s (remain 8m 48s) Score: 44.2813 -> 44.3969 & unselected: region_mean_elapsed_years_encoding
# [266/270]Elapsed 469m 21s (remain 7m 3s) Score: 44.2813 -> 44.3340 & unselected: state_min_encoding
# [267/270]Elapsed 471m 11s (remain 5m 17s) Score: 44.2813 -> 44.3724 & unselected: region_median_encoding
# [268/270]Elapsed 473m 2s (remain 3m 31s) Score: 44.2813 -> 44.3786 & unselected: region_std_elapsed_years_encoding
# [269/270]Elapsed 474m 46s (remain 1m 45s) Score: 44.2813 -> 44.3609 & unselected: state_mean_odometer_encoding
# [270/270]Elapsed 476m 27s (remain 0m 0s) Score: 44.2813 -> 44.3423 & unselected: drive_max_elapsed_years_encoding

# %%
# ===================================================================
#  simple greedy forward selection
# ===================================================================
lgb_param = {
    "task":"train",
    "objective": "mape",
    "boosting":"gbdt",
    "num_boost_round": CFG.num_boost_round,
    "learning_rate":0.1, # default: 0.1
    "num_leaves":31, # max number of leaves in one tree ###
    "max_depth":6, # default -1, int: limit the max depth for tree model ###
    "min_child_weight":1e-3, # double: minimal sum hessian in one leaf
    "min_data_in_leaf":20, # minimal number of data in one leaf
    "alpha":0.9, # double, constraints, alpha > 0.0: 
    "colsample_bytree":0.4, # 0 < "colsample_bytree" < 1 ###
    #: LightGBM will randomly select a subset of features on each iteration (tree) if feature_fraction is smaller than 1.0
    "lambda": 0, #lambda_l2 >= 0.0: L2 regularization
    "subsample":1, #0.0 < bagging_fraction <= 1.0
    "num_threads": CFG.num_cores,
    "metric": 'mape',
    "seed" : CFG.seed,
    "verbosity": -1, 
}

print('\033[32m'+"start simple selection"+'\033[0m')
best_score = train_lgb(CFG, lgb_param)
print(f"[{0}/{len(CFG.candidates)}]Base Score: {best_score:.3f}")

CFG.greedy_seed += 10000
start = time.time()
CFG.candidates = np.random.RandomState(CFG.greedy_seed).permutation(CFG.candidates)
for i, col in enumerate(CFG.candidates):
    CFG.use_features.append(col)
    score = train_lgb(CFG, lgb_param)
    if best_score > score:
        print('[{0}/{1}]'
              'Elapsed {remain:s} '
              'Score: {best_score:.4f} -> {score:.4f} '
              '&   selected: {feature}'
              .format(i+1, len(CFG.candidates),
                      remain=timeSince(start, float(i+1)/len(CFG.candidates) ),
                      best_score = best_score,
                      score = score,
                      feature = col
                     )
             )
        best_score = score
    else:
        print('[{0}/{1}]'
              'Elapsed {remain:s} '
              'Score: {best_score:.4f} -> {score:.4f} '
              '& unselected: {feature}'
              .format(i+1, len(CFG.candidates),
                      remain=timeSince(start, float(i+1)/len(CFG.candidates) ),
                      best_score = best_score,
                      score = score,
                      feature = col
                     )
             )
        CFG.use_features.remove(col)
# Out:
# start simple selection
# [0/270]Base Score: 44.281
# [1/270]Elapsed 1m 37s (remain 438m 15s) Score: 44.2813 -> 44.3817 & unselected: transmission_median_elapsed_years_encoding
# [2/270]Elapsed 3m 22s (remain 451m 50s) Score: 44.2813 -> 44.3550 & unselected: cylinders_std_encoding
# [3/270]Elapsed 5m 8s (remain 458m 13s) Score: 44.2813 -> 44.3414 & unselected: type_category
# [4/270]Elapsed 6m 50s (remain 454m 42s) Score: 44.2813 -> 44.3994 & unselected: type_mean_elapsed_years_encoding_diff
# [5/270]Elapsed 8m 30s (remain 450m 36s) Score: 44.2813 -> 44.3533 & unselected: size_std_odometer_encoding
# [6/270]Elapsed 10m 18s (remain 453m 12s) Score: 44.2813 -> 44.3523 & unselected: title_status_std_elapsed_years_encoding
# [7/270]Elapsed 12m 5s (remain 454m 17s) Score: 44.2813 -> 44.4035 & unselected: paint_color_mean_elapsed_years_encoding_diff
# [8/270]Elapsed 13m 51s (remain 453m 55s) Score: 44.2813 -> 44.3718 & unselected: manufacturer_median_elapsed_years_encoding_diff
# [9/270]Elapsed 15m 35s (remain 451m 55s) Score: 44.2813 -> 44.3836 & unselected: manufacturer_median_encoding
# [10/270]Elapsed 17m 14s (remain 448m 25s) Score: 44.2813 -> 44.3734 & unselected: state_min_odometer_encoding
# [11/270]Elapsed 18m 57s (remain 446m 11s) Score: 44.2813 -> 44.3340 & unselected: drive_mean_odometer_encoding_diff
# [12/270]Elapsed 20m 37s (remain 443m 27s) Score: 44.2813 -> 44.3269 & unselected: type_count_encoding
# [13/270]Elapsed 22m 18s (remain 441m 7s) Score: 44.2813 -> 44.3143 & unselected: condition_mean_encoding
# [14/270]Elapsed 24m 6s (remain 440m 57s) Score: 44.2813 -> 44.3797 & unselected: region_mean_elapsed_years_encoding_diff
# [15/270]Elapsed 25m 44s (remain 437m 40s) Score: 44.2813 -> 44.3510 & unselected: title_status_median_odometer_encoding
# [16/270]Elapsed 27m 31s (remain 436m 51s) Score: 44.2813 -> 44.3882 & unselected: size_std_encoding
# [17/270]Elapsed 29m 9s (remain 433m 49s) Score: 44.2813 -> 44.3720 & unselected: cylinders_mean_elapsed_years_encoding
# [18/270]Elapsed 30m 52s (remain 432m 11s) Score: 44.2813 -> 44.3791 & unselected: region_max_encoding
# [19/270]Elapsed 32m 29s (remain 429m 13s) Score: 44.2813 -> 44.3981 & unselected: transmission_std_odometer_encoding
# [20/270]Elapsed 34m 7s (remain 426m 31s) Score: 44.2813 -> 44.3620 & unselected: region_median_odometer_encoding_diff
# [21/270]Elapsed 35m 46s (remain 424m 6s) Score: 44.2813 -> 44.3353 & unselected: type_max_encoding
# [22/270]Elapsed 37m 23s (remain 421m 32s) Score: 44.2813 -> 44.3565 & unselected: state_std_elapsed_years_encoding
# [23/270]Elapsed 39m 0s (remain 418m 50s) Score: 44.2813 -> 44.3499 & unselected: paint_color_max_odometer_encoding
# [24/270]Elapsed 40m 36s (remain 416m 17s) Score: 44.2813 -> 44.3858 & unselected: state_std_odometer_encoding
# [25/270]Elapsed 42m 17s (remain 414m 23s) Score: 44.2813 -> 44.3882 & unselected: cylinders_mean_elapsed_years_encoding_diff
# [26/270]Elapsed 43m 57s (remain 412m 32s) Score: 44.2813 -> 44.2840 & unselected: log_elapsed_years*odometer
# [27/270]Elapsed 45m 35s (remain 410m 17s) Score: 44.2813 -> 44.3610 & unselected: cylinders_median_odometer_encoding_diff
# [28/270]Elapsed 47m 14s (remain 408m 18s) Score: 44.2813 -> 44.3466 & unselected: drive_median_encoding
# [29/270]Elapsed 48m 56s (remain 406m 40s) Score: 44.2813 -> 44.3428 & unselected: fuel_std_encoding
# [30/270]Elapsed 50m 44s (remain 405m 56s) Score: 44.2813 -> 44.3405 & unselected: type_median_elapsed_years_encoding
# [31/270]Elapsed 52m 32s (remain 405m 6s) Score: 44.2813 -> 44.3387 & unselected: cylinders_category
# [32/270]Elapsed 54m 11s (remain 403m 6s) Score: 44.2813 -> 44.3483 & unselected: condition_max_encoding
# [LightGBM] [Fatal] Feature (cylinders_mean_odometer_encoding) appears more than one time.
# ---------------------------------------------------------------------------
# LightGBMError                             Traceback (most recent call last)
# Cell In[12], line 34
#      32 for i, col in enumerate(CFG.candidates):
#      33     CFG.use_features.append(col)
# ---> 34     score = train_lgb(CFG, lgb_param)
#      35     if best_score > score:
#      36         print('[{0}/{1}]'
#      37               'Elapsed {remain:s} '
#      38               'Score: {best_score:.4f} -> {score:.4f} '
#    (...)
#      45                      )
#      46              )
#
# Cell In[10], line 11, in train_lgb(CFG, lgb_param)
#       9 lgb_train = lgb.Dataset(X_train[CFG.use_features], X_train["price"], categorical_feature = categorical_features,)
#      10 lgb_valid = lgb.Dataset(X_valid[CFG.use_features], X_valid["price"], categorical_feature = categorical_features,)
# ---> 11 model = lgb.train(
#      12                 lgb_param,
#      13                 lgb_train,
#      14                 valid_sets=[lgb_valid],
#      15                 categorical_feature = categorical_features,
#      16                 callbacks=[lgb.early_stopping(stopping_rounds=CFG.stopping_rounds, verbose=False),],
#      17                 )
#      19 X_valid[f"pred"] = model.predict(X_valid[CFG.use_features], num_iteration=model.best_iteration)
#      20 oof_df = pd.concat([oof_df, X_valid], ignore_index=True)
#
# File /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:245, in train(params, train_set, num_boost_round, valid_sets, valid_names, feval, init_model, feature_name, categorical_feature, keep_training_booster, callbacks)
#     243 # construct booster
#     244 try:
# --> 245     booster = Booster(params=params, train_set=train_set)
#     246     if is_valid_contain_train:
#     247         booster.set_train_data_name(train_data_name)
#
# File /opt/conda/lib/python3.10/site-packages/lightgbm/basic.py:3096, in Booster.__init__(self, params, train_set, model_file, model_str)
#    3089     self.set_network(
#    3090         machines=machines,
#    3091         local_listen_port=params["local_listen_port"],
#    3092         listen_time_out=params.get("time_out", 120),
#    3093         num_machines=params["num_machines"]
#    3094     )
#    3095 # construct booster object
# -> 3096 train_set.construct()
#    3097 # copy the parameters from train_set
#    3098 params.update(train_set.get_params())
#
# File /opt/conda/lib/python3.10/site-packages/lightgbm/basic.py:2210, in Dataset.construct(self)
#    2203             self._set_init_score_by_predictor(
#    2204                 predictor=self._predictor,
#    2205                 data=self.data,
#    2206                 used_indices=used_indices
#    2207             )
#    2208 else:
#    2209     # create train
# -> 2210     self._lazy_init(data=self.data, label=self.label, reference=None,
#    2211                     weight=self.weight, group=self.group,
#    2212                     init_score=self.init_score, predictor=self._predictor,
#    2213                     feature_name=self.feature_name, categorical_feature=self.categorical_feature, params=self.params)
#    2214 if self.free_raw_data:
#    2215     self.data = None
#
# File /opt/conda/lib/python3.10/site-packages/lightgbm/basic.py:1895, in Dataset._lazy_init(self, data, label, reference, weight, group, init_score, predictor, feature_name, categorical_feature, params)
#    1893     raise TypeError(f'Wrong predictor type {type(predictor).__name__}')
#    1894 # set feature names
# -> 1895 return self.set_feature_name(feature_name)
#
# File /opt/conda/lib/python3.10/site-packages/lightgbm/basic.py:2569, in Dataset.set_feature_name(self, feature_name)
#    2567         raise ValueError(f"Length of feature_name({len(feature_name)}) and num_feature({self.num_feature()}) don't match")
#    2568     c_feature_name = [_c_str(name) for name in feature_name]
# -> 2569     _safe_call(_LIB.LGBM_DatasetSetFeatureNames(
#    2570         self._handle,
#    2571         _c_array(ctypes.c_char_p, c_feature_name),
#    2572         ctypes.c_int(len(feature_name))))
#    2573 return self
#
# File /opt/conda/lib/python3.10/site-packages/lightgbm/basic.py:237, in _safe_call(ret)
#     229 """Check the return value from C API call.
#     230
#     231 Parameters
#    (...)
#     234     The return value from C API calls.
#     235 """
#     236 if ret != 0:
# --> 237     raise LightGBMError(_LIB.LGBM_GetLastError().decode('utf-8'))
#
# LightGBMError: Feature (cylinders_mean_odometer_encoding) appears more than one time.
