# %%
from tqdm.auto import tqdm
import warnings
warnings.simplefilter("ignore")

# %%
for SEED in tqdm([0, 1, 2]):
    # !python /kaggle/input/greedy/greedy/run.py\
    --greedy_seed $SEED\
    --save_dir /kaggle/working/\
    --data_dir /kaggle/input/signate-studentcup2023/
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# ...
# seed: 42
# greedy_type: simple
# greedy_seed: 0
# n_splits: 5
# data_dir: /kaggle/input/signate-studentcup2023/
# target_bins: 20
# year_bins: 20
# num_boost_round: 10000
# stopping_rounds: 1500
# save_dir: /kaggle/working/
# base_features: ['year', 'odometer']
# debug: False
# num_cores: 4
# categorical_features: ['fuel', 'title_status', 'type', 'state', 'region', 'manufacturer', 'condition', 'cylinders', 'transmission', 'drive', 'size', 'paint_color']
# candidate_features: []
# 1.0    5507
# 0.0    5507
# 2.0    5506
# 4.0    5506
# 3.0    5506
# Name: fold, dtype: int64
# Variance between folds' means 8.784566908616718
# start simple selection
# base features:  ['year', 'odometer']
# [0/84]Base Score: 49.239
# [1/84]Score: 49.239 -> 49.188 &   selected: state_min_encoding
# [2/84]Score: 49.188 -> 47.449 &   selected: manufacturer_min_encoding
# [3/84]Score: 47.449 -> 46.734 &   selected: condition_std_encoding
# ...
