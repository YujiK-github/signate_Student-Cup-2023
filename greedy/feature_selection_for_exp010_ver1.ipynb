# %%
for SEED in [42, 2023]:
    # !python /kaggle/input/greedy-selection/greedy/run.py\
    --greedy_seed $SEED\
    --save_dir /kaggle/working/\
    --data_dir /kaggle/input/signate-studentcup2023/
# Out:
# ================================================================================
# seed: 42
# greedy_type: rule_base
# greedy_seed: 42
# n_splits: 5
# filename: exp010
# data_dir: /kaggle/input/signate-studentcup2023/
# year_bins: 20
# num_boost_round: 10000
# stopping_rounds: 1500
# save_dir: /kaggle/working/
# base_features: ['year', 'odometer', 'fuel_category', 'title_status_category', 'type_category', 'state_category', 'region_category', 'manufacturer_category', 'condition_category', 'cylinders_category', 'transmission_category', 'drive_category', 'size_category', 'paint_color_category']
# debug: False
# num_cores: 4
# categorical_features: ['fuel', 'title_status', 'type', 'state', 'region', 'manufacturer', 'condition', 'cylinders', 'transmission', 'drive', 'size', 'paint_color']
# candidate_features: []
# 0    5507
# 1    5507
# 3    5506
# 2    5506
# 4    5506
# Name: fold, dtype: int64
# The variance of the mean of the folds:  4.695908800203918
# start simple selection
# base features:  ['year', 'odometer', 'fuel_category', 'title_status_category', 'type_category', 'state_category', 'region_category', 'manufacturer_category', 'condition_category', 'cylinders_category', 'transmission_category', 'drive_category', 'size_category', 'paint_color_category']
# [0/12]Base Score: 45.508
# [1/12]Start Feature selection about size
#  size_category -> 45.50800
#  size_count_encoding -> 45.52224
#  size_mean_encoding -> 45.45239
#  size_median_encoding -> 45.48239
#  size_std_encoding -> 45.45239
#  size_min_encoding -> 45.49070
#  size_max_encoding -> 45.52224
#     Selected :size_mean_encoding -> 45.45239
#         Unselected size_count_encoding: 45.452386 -> 45.46080
# [2/12]Start Feature selection about drive
#  drive_category -> 45.45239
#  drive_count_encoding -> 45.52941
#  drive_mean_encoding -> 45.51564
#  drive_median_encoding -> 45.51564
#  drive_std_encoding -> 45.51564
#  drive_min_encoding -> 45.58562
#  drive_max_encoding -> 45.51564
#     Selected :drive_category -> 45.45239
# [3/12]Start Feature selection about fuel
#  fuel_category -> 45.45239
#  fuel_count_encoding -> 45.55621
#  fuel_mean_encoding -> 45.51398
#  fuel_median_encoding -> 45.58584
#  fuel_std_encoding -> 45.54034
#  fuel_min_encoding -> 45.49387
#  fuel_max_encoding -> 45.54012
#     Selected :fuel_category -> 45.45239
# [4/12]Start Feature selection about transmission
#  transmission_category -> 45.45239
#  transmission_count_encoding -> 45.48261
#  transmission_mean_encoding -> 45.46357
#  transmission_median_encoding -> 45.45331
#  transmission_std_encoding -> 45.48261
#  transmission_min_encoding -> 45.48706
#  transmission_max_encoding -> 45.48261
#     Selected :transmission_category -> 45.45239
# [5/12]Start Feature selection about manufacturer
#  manufacturer_category -> 45.45239
#  manufacturer_count_encoding -> 45.58411
#  manufacturer_mean_encoding -> 45.47595
#  manufacturer_median_encoding -> 45.41568
#  manufacturer_std_encoding -> 45.43442
#  manufacturer_min_encoding -> 45.64722
#  manufacturer_max_encoding -> 45.58419
#     Selected :manufacturer_median_encoding -> 45.41568
#         Unselected manufacturer_max_encoding: 45.415679 -> 45.45339
# [6/12]Start Feature selection about type
#  type_category -> 45.41568
#  type_count_encoding -> 45.58595
#  type_mean_encoding -> 45.50948
#  type_median_encoding -> 45.41440
#  type_std_encoding -> 45.51226
#  type_min_encoding -> 45.58053
#  type_max_encoding -> 45.49343
#     Selected :type_median_encoding -> 45.41440
#         Unselected type_min_encoding: 45.414399 -> 45.42496
# [7/12]Start Feature selection about title_status
#  title_status_category -> 45.41440
#  title_status_count_encoding -> 45.49194
#  title_status_mean_encoding -> 45.43653
#  title_status_median_encoding -> 45.42144
#  title_status_std_encoding -> 45.40331
#  title_status_min_encoding -> 45.48102
#  title_status_max_encoding -> 45.39141
#     Selected :title_status_max_encoding -> 45.39141
#         Unselected title_status_min_encoding: 45.391409 -> 45.40764
# [8/12]Start Feature selection about paint_color
#  paint_color_category -> 45.39141
#  paint_color_count_encoding -> 45.54965
#  paint_color_mean_encoding -> 45.39481
#  paint_color_median_encoding -> 45.51325
#  paint_color_std_encoding -> 45.47362
#  paint_color_min_encoding -> 45.48791
#  paint_color_max_encoding -> 45.55535
#     Selected :paint_color_category -> 45.39141
# [9/12]Start Feature selection about region
#  region_category -> 45.39141
#  region_count_encoding -> 44.81937
#  region_mean_encoding -> 44.89918
#  region_median_encoding -> 44.81167
#  region_std_encoding -> 44.80469
#  region_min_encoding -> 44.81688
#  region_max_encoding -> 44.81322
#     Selected :region_std_encoding -> 44.80469
#         Unselected region_mean_encoding: 44.804690 -> 44.86894
# [10/12]Start Feature selection about cylinders
#  cylinders_category -> 44.80469
#  cylinders_count_encoding -> 44.82184
#  cylinders_mean_encoding -> 44.74656
#  cylinders_median_encoding -> 44.79122
#  cylinders_std_encoding -> 44.77928
#  cylinders_min_encoding -> 44.82514
#  cylinders_max_encoding -> 44.77405
#     Selected :cylinders_mean_encoding -> 44.74656
#         Unselected cylinders_count_encoding: 44.746560 -> 44.79346
# [11/12]Start Feature selection about state
#  state_category -> 44.74656
#  state_count_encoding -> 44.46060
#  state_mean_encoding -> 44.45773
#  state_median_encoding -> 44.49020
#  state_std_encoding -> 44.52865
#  state_min_encoding -> 44.47890
#  state_max_encoding -> 44.48307
#     Selected :state_mean_encoding -> 44.45773
#         Unselected state_std_encoding: 44.457733 -> 44.50775
# [12/12]Start Feature selection about condition
#  condition_category -> 44.45773
#  condition_count_encoding -> 44.65394
#  condition_mean_encoding -> 44.36457
#  condition_median_encoding -> 44.39051
#  condition_std_encoding -> 44.42038
#  condition_min_encoding -> 44.53038
#  condition_max_encoding -> 44.43624
#     Selected :condition_mean_encoding -> 44.36457
#         Unselected condition_min_encoding: 44.364569 -> 44.44873
# selected features: ['year', 'odometer', 'size_mean_encoding', 'drive_category', 'fuel_category', 'transmission_category', 'manufacturer_median_encoding', 'type_median_encoding', 'title_status_max_encoding', 'paint_color_category', 'region_std_encoding', 'cylinders_mean_encoding', 'state_mean_encoding', 'condition_mean_encoding']
# best_score: 44.364568837517524
# Saved to /kaggle/working/selected_features_for_exp010_seed42.pickle!
# ================================================================================
# seed: 42
# greedy_type: rule_base
# greedy_seed: 2023
# n_splits: 5
# filename: exp010
# data_dir: /kaggle/input/signate-studentcup2023/
# year_bins: 20
# num_boost_round: 10000
# stopping_rounds: 1500
# save_dir: /kaggle/working/
# base_features: ['year', 'odometer', 'fuel_category', 'title_status_category', 'type_category', 'state_category', 'region_category', 'manufacturer_category', 'condition_category', 'cylinders_category', 'transmission_category', 'drive_category', 'size_category', 'paint_color_category']
# debug: False
# num_cores: 4
# categorical_features: ['fuel', 'title_status', 'type', 'state', 'region', 'manufacturer', 'condition', 'cylinders', 'transmission', 'drive', 'size', 'paint_color']
# candidate_features: []
# 0    5507
# 1    5507
# 3    5506
# 2    5506
# 4    5506
# Name: fold, dtype: int64
# The variance of the mean of the folds:  4.695908800203918
# start simple selection
# base features:  ['year', 'odometer', 'fuel_category', 'title_status_category', 'type_category', 'state_category', 'region_category', 'manufacturer_category', 'condition_category', 'cylinders_category', 'transmission_category', 'drive_category', 'size_category', 'paint_color_category']
# [0/12]Base Score: 45.508
# [1/12]Start Feature selection about manufacturer
#  manufacturer_category -> 45.50800
#  manufacturer_min_encoding -> 45.67980
#  manufacturer_std_encoding -> 45.45817
#  manufacturer_max_encoding -> 45.60979
#  manufacturer_count_encoding -> 45.65949
#  manufacturer_median_encoding -> 45.43036
#  manufacturer_mean_encoding -> 45.49169
#     Selected :manufacturer_median_encoding -> 45.43036
#         Unselected manufacturer_count_encoding: 45.430362 -> 45.46521
# [2/12]Start Feature selection about transmission
#  transmission_category -> 45.43036
#  transmission_min_encoding -> 45.44240
#  transmission_std_encoding -> 45.44854
#  transmission_max_encoding -> 45.44854
#  transmission_count_encoding -> 45.44854
#  transmission_median_encoding -> 45.45079
#  transmission_mean_encoding -> 45.44855
#     Selected :transmission_category -> 45.43036
# [3/12]Start Feature selection about type
#  type_category -> 45.43036
#  type_min_encoding -> 45.57698
#  type_std_encoding -> 45.46027
#  type_max_encoding -> 45.52388
#  type_count_encoding -> 45.59530
#  type_median_encoding -> 45.33644
#  type_mean_encoding -> 45.40361
#     Selected :type_median_encoding -> 45.33644
#         Unselected type_min_encoding: 45.336437 -> 45.42477
# [4/12]Start Feature selection about fuel
#  fuel_category -> 45.33644
#  fuel_min_encoding -> 45.46907
#  fuel_std_encoding -> 45.43210
#  fuel_max_encoding -> 45.40555
#  fuel_count_encoding -> 45.49942
#  fuel_median_encoding -> 45.39061
#  fuel_mean_encoding -> 45.43151
#     Selected :fuel_category -> 45.33644
# [5/12]Start Feature selection about size
#  size_category -> 45.33644
#  size_min_encoding -> 45.37306
#  size_std_encoding -> 45.41440
#  size_max_encoding -> 45.39376
#  size_count_encoding -> 45.39376
#  size_median_encoding -> 45.41992
#  size_mean_encoding -> 45.41440
#     Selected :size_category -> 45.33644
# [6/12]Start Feature selection about state
#  state_category -> 45.33644
#  state_min_encoding -> 45.37322
#  state_std_encoding -> 45.44553
#  state_max_encoding -> 45.42423
#  state_count_encoding -> 45.45948
#  state_median_encoding -> 45.41795
#  state_mean_encoding -> 45.37613
#     Selected :state_category -> 45.33644
# [7/12]Start Feature selection about region
#  region_category -> 45.33644
#  region_min_encoding -> 44.88025
#  region_std_encoding -> 44.79523
#  region_max_encoding -> 44.74595
#  region_count_encoding -> 44.83353
#  region_median_encoding -> 44.86822
#  region_mean_encoding -> 44.86163
#     Selected :region_max_encoding -> 44.74595
#         Unselected region_min_encoding: 44.745955 -> 44.87657
# [8/12]Start Feature selection about title_status
#  title_status_category -> 44.74595
#  title_status_min_encoding -> 44.77640
#  title_status_std_encoding -> 44.79557
#  title_status_max_encoding -> 44.87309
#  title_status_count_encoding -> 44.82083
#  title_status_median_encoding -> 44.83264
#  title_status_mean_encoding -> 44.79983
#     Selected :title_status_category -> 44.74595
# [9/12]Start Feature selection about paint_color
#  paint_color_category -> 44.74595
#  paint_color_min_encoding -> 44.79442
#  paint_color_std_encoding -> 44.79723
#  paint_color_max_encoding -> 44.85922
#  paint_color_count_encoding -> 44.83096
#  paint_color_median_encoding -> 44.77083
#  paint_color_mean_encoding -> 44.82310
#     Selected :paint_color_category -> 44.74595
# [10/12]Start Feature selection about condition
#  condition_category -> 44.74595
#  condition_min_encoding -> 44.92362
#  condition_std_encoding -> 44.74468
#  condition_max_encoding -> 44.82345
#  condition_count_encoding -> 44.88836
#  condition_median_encoding -> 44.70657
#  condition_mean_encoding -> 44.72455
#     Selected :condition_median_encoding -> 44.70657
#         Unselected condition_count_encoding: 44.706571 -> 44.74797
# [11/12]Start Feature selection about drive
#  drive_category -> 44.70657
#  drive_min_encoding -> 44.81836
#  drive_std_encoding -> 44.73895
#  drive_max_encoding -> 44.73895
#  drive_count_encoding -> 44.83540
#  drive_median_encoding -> 44.73895
#  drive_mean_encoding -> 44.73895
#     Selected :drive_category -> 44.70657
# [12/12]Start Feature selection about cylinders
#  cylinders_category -> 44.70657
#  cylinders_min_encoding -> 44.77062
#  cylinders_std_encoding -> 44.71682
#  cylinders_max_encoding -> 44.79722
#  cylinders_count_encoding -> 44.82849
#  cylinders_median_encoding -> 44.78435
#  cylinders_mean_encoding -> 44.74720
#     Selected :cylinders_category -> 44.70657
# selected features: ['year', 'odometer', 'manufacturer_median_encoding', 'transmission_category', 'type_median_encoding', 'fuel_category', 'size_category', 'state_category', 'region_max_encoding', 'title_status_category', 'paint_color_category', 'condition_median_encoding', 'drive_category', 'cylinders_category']
# best_score: 44.706570976834534
# Saved to /kaggle/working/selected_features_for_exp010_seed2023.pickle!
