# %%
from tqdm.auto import tqdm
import warnings
warnings.simplefilter("ignore")

# %%
for SEED in tqdm([42, 2023, 0, 1, 2]):
    # !python run.py\
    --greedy_seed $SEED \
    --greedy_fold 0
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# ...
# seed: 42
# greedy_type: simple
# greedy_seed: 42
# greedy_fold: 0
# n_splits: 5
# data_dir: G:/マイドライブ/signate_StudentCup2023/data/
# target_bins: 20
# year_bins: 20
# num_boost_round: 10000
# stopping_rounds: 1500
# save_dir: G:/マイドライブ/signate_StudentCup2023/data/
# base_features: ['year', 'odometer']
# debug: False
# num_cores: 8
# categorical_features: ['fuel', 'title_status', 'type', 'state', 'region', 'manufacturer', 'condition', 'cylinders', 'transmission', 'drive', 'size', 'paint_color']
# candidate_features: []
# fold
# 1.0    5507
# 0.0    5507
# 2.0    5506
# 4.0    5506
# 3.0    5506
# Name: count, dtype: int64
# Variance between folds' means 8.784566908616718
# start simple selection
# base features:  ['year', 'odometer']
# [0/84]Base Score: 49.535
# [1/84]Score: 49.535 -> 49.243 &   selected: title_status_category
# [2/84]Score: 49.243 -> 48.079 &   selected: fuel_count_encoding
# ...
