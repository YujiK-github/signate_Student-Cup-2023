# %%
from tqdm.auto import tqdm
import warnings
warnings.simplefilter("ignore")

# %%
for SEED in tqdm([42, 2023]):
    # !python /kaggle/input/greedy/greedy/run.py\
    --greedy_seed $SEED\
    --save_dir /kaggle/working/\
    --data_dir /kaggle/input/signate-studentcup2023/
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
# ================================================================================
# seed: 42
# greedy_type: simple
# greedy_seed: 42
# n_splits: 5
# data_dir: /kaggle/input/signate-studentcup2023/
# target_bins: 20
# year_bins: 20
# num_boost_round: 10000
# stopping_rounds: 1500
# save_dir: /kaggle/working/
# base_features: ['year', 'odometer']
# debug: False
# num_cores: 4
# categorical_features: ['fuel', 'title_status', 'type', 'state', 'region', 'manufacturer', 'condition', 'cylinders', 'transmission', 'drive', 'size', 'paint_color']
# candidate_features: []
# 1.0    5507
# 0.0    5507
# 2.0    5506
# 4.0    5506
# 3.0    5506
# Name: fold, dtype: int64
# Variance between folds' means 8.784566908616718
# start simple selection
# base features:  ['year', 'odometer']
# [0/84]Base Score: 49.239
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [1/84]Score: 49.239 -> 49.138 &   selected: title_status_category
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [2/84]Score: 49.138 -> 47.907 &   selected: fuel_count_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [3/84]Score: 47.907 -> 46.080 &   selected: drive_std_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [4/84]Score: 46.080 -> 45.647 &   selected: type_mean_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [5/84]Score: 45.647 -> 45.676 & unselected: fuel_mean_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [6/84]Score: 45.647 -> 45.271 &   selected: paint_color_min_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [7/84]Score: 45.271 -> 45.271 & unselected: size_count_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [8/84]Score: 45.271 -> 45.298 & unselected: title_status_std_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [9/84]Score: 45.271 -> 45.465 & unselected: region_count_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [10/84]Score: 45.271 -> 45.278 & unselected: size_min_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [11/84]Score: 45.271 -> 45.214 &   selected: manufacturer_min_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [12/84]Score: 45.214 -> 45.123 &   selected: cylinders_mean_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [13/84]Score: 45.123 -> 45.342 & unselected: region_min_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [14/84]Score: 45.123 -> 45.126 & unselected: drive_category
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [15/84]Score: 45.123 -> 45.154 & unselected: transmission_min_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [16/84]Score: 45.123 -> 45.154 & unselected: transmission_max_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [17/84]Score: 45.123 -> 45.168 & unselected: region_std_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [18/84]Score: 45.123 -> 46.269 & unselected: region_category
# [19/84]Score: 45.123 -> 44.424 &   selected: condition_mean_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [20/84]Score: 44.424 -> 44.341 &   selected: cylinders_max_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [21/84]Score: 44.341 -> 44.435 & unselected: paint_color_count_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [22/84]Score: 44.341 -> 44.484 & unselected: state_min_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [23/84]Score: 44.341 -> 44.383 & unselected: manufacturer_max_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [24/84]Score: 44.341 -> 44.446 & unselected: state_std_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [25/84]Score: 44.341 -> 44.444 & unselected: drive_count_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [26/84]Score: 44.341 -> 44.447 & unselected: paint_color_std_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [27/84]Score: 44.341 -> 44.446 & unselected: manufacturer_count_encoding
# [28/84]Score: 44.341 -> 44.415 & unselected: condition_min_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [29/84]Score: 44.341 -> 44.454 & unselected: state_median_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [30/84]Score: 44.341 -> 44.464 & unselected: region_max_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [31/84]Score: 44.341 -> 44.385 & unselected: condition_max_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [32/84]Score: 44.341 -> 44.433 & unselected: paint_color_category
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [33/84]Score: 44.341 -> 44.395 & unselected: fuel_median_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [34/84]Score: 44.341 -> 44.382 & unselected: size_max_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [35/84]Score: 44.341 -> 44.331 &   selected: cylinders_count_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [36/84]Score: 44.331 -> 44.414 & unselected: paint_color_mean_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [37/84]Score: 44.331 -> 44.402 & unselected: transmission_median_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [38/84]Score: 44.331 -> 44.375 & unselected: title_status_max_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [39/84]Score: 44.331 -> 44.436 & unselected: paint_color_max_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [40/84]Score: 44.331 -> 44.409 & unselected: type_min_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [41/84]Score: 44.331 -> 44.398 & unselected: transmission_std_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [42/84]Score: 44.331 -> 44.399 & unselected: fuel_std_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [43/84]Score: 44.331 -> 44.379 & unselected: size_mean_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [44/84]Score: 44.331 -> 44.419 & unselected: state_count_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [45/84]Score: 44.331 -> 44.383 & unselected: title_status_mean_encoding
# [46/84]Score: 44.331 -> 44.301 &   selected: manufacturer_std_encoding
# [47/84]Score: 44.301 -> 44.329 & unselected: transmission_count_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [48/84]Score: 44.301 -> 44.331 & unselected: size_median_encoding
# [49/84]Score: 44.301 -> 44.357 & unselected: condition_count_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [50/84]Score: 44.301 -> 44.430 & unselected: region_median_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [51/84]Score: 44.301 -> 44.774 & unselected: state_category
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [52/84]Score: 44.301 -> 44.301 & unselected: drive_median_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [53/84]Score: 44.301 -> 44.342 & unselected: cylinders_min_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [54/84]Score: 44.301 -> 44.319 & unselected: condition_median_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [55/84]Score: 44.301 -> 44.301 & unselected: size_category
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [56/84]Score: 44.301 -> 44.284 &   selected: fuel_min_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [57/84]Score: 44.284 -> 44.402 & unselected: state_mean_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [58/84]Score: 44.284 -> 44.288 & unselected: manufacturer_median_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [59/84]Score: 44.284 -> 44.365 & unselected: type_median_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [60/84]Score: 44.284 -> 44.293 & unselected: cylinders_std_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [61/84]Score: 44.284 -> 44.347 & unselected: type_max_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [62/84]Score: 44.284 -> 44.287 & unselected: condition_std_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [63/84]Score: 44.284 -> 44.347 & unselected: transmission_category
# [64/84]Score: 44.284 -> 44.441 & unselected: manufacturer_category
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [65/84]Score: 44.284 -> 44.283 &   selected: drive_mean_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [66/84]Score: 44.283 -> 44.442 & unselected: region_mean_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [67/84]Score: 44.283 -> 44.364 & unselected: cylinders_category
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [68/84]Score: 44.283 -> 44.283 & unselected: drive_max_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [69/84]Score: 44.283 -> 44.320 & unselected: size_std_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [70/84]Score: 44.283 -> 44.274 &   selected: fuel_category
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [71/84]Score: 44.274 -> 44.345 & unselected: manufacturer_mean_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [72/84]Score: 44.274 -> 44.410 & unselected: state_max_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [73/84]Score: 44.274 -> 44.295 & unselected: title_status_count_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [74/84]Score: 44.274 -> 44.339 & unselected: transmission_mean_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [75/84]Score: 44.274 -> 44.340 & unselected: title_status_median_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [76/84]Score: 44.274 -> 44.349 & unselected: type_count_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [77/84]Score: 44.274 -> 44.377 & unselected: type_std_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [78/84]Score: 44.274 -> 44.305 & unselected: condition_category
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [79/84]Score: 44.274 -> 44.325 & unselected: type_category
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [80/84]Score: 44.274 -> 44.303 & unselected: title_status_min_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [81/84]Score: 44.274 -> 44.310 & unselected: drive_min_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [82/84]Score: 44.274 -> 44.390 & unselected: paint_color_median_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [83/84]Score: 44.274 -> 44.370 & unselected: fuel_max_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [84/84]Score: 44.274 -> 44.287 & unselected: cylinders_median_encoding
# selected features: ['fuel_min_encoding', 'condition_mean_encoding', 'manufacturer_std_encoding', 'title_status_category', 'manufacturer_min_encoding', 'drive_mean_encoding', 'drive_std_encoding', 'cylinders_mean_encoding', 'cylinders_max_encoding', 'fuel_category', 'paint_color_min_encoding', 'cylinders_count_encoding', 'fuel_count_encoding', 'type_mean_encoding', 'year', 'odometer']
# best_score: 44.2737074136517
# Saved selected features!
# ================================================================================
# seed: 42
# greedy_type: simple
# greedy_seed: 2023
# n_splits: 5
# data_dir: /kaggle/input/signate-studentcup2023/
# target_bins: 20
# year_bins: 20
# num_boost_round: 10000
# stopping_rounds: 1500
# save_dir: /kaggle/working/
# base_features: ['year', 'odometer']
# debug: False
# num_cores: 4
# categorical_features: ['fuel', 'title_status', 'type', 'state', 'region', 'manufacturer', 'condition', 'cylinders', 'transmission', 'drive', 'size', 'paint_color']
# candidate_features: []
# 1.0    5507
# 0.0    5507
# 2.0    5506
# 4.0    5506
# 3.0    5506
# Name: fold, dtype: int64
# Variance between folds' means 8.784566908616718
# start simple selection
# base features:  ['year', 'odometer']
# [0/84]Base Score: 49.239
# [1/84]Score: 49.239 -> 48.530 &   selected: condition_mean_encoding
# [2/84]Score: 48.530 -> 47.215 &   selected: fuel_count_encoding
# [3/84]Score: 47.215 -> 47.125 &   selected: title_status_std_encoding
# [4/84]Score: 47.125 -> 47.131 & unselected: fuel_median_encoding
# [5/84]Score: 47.125 -> 47.111 &   selected: transmission_category
# [6/84]Score: 47.111 -> 45.281 &   selected: drive_category
# [7/84]Score: 45.281 -> 45.295 & unselected: condition_max_encoding
# [8/84]Score: 45.281 -> 45.347 & unselected: state_min_encoding
# [9/84]Score: 45.281 -> 44.941 &   selected: type_count_encoding
# [10/84]Score: 44.941 -> 44.990 & unselected: title_status_min_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [11/84]Score: 44.941 -> 44.945 & unselected: title_status_category
# [12/84]Score: 44.941 -> 45.083 & unselected: region_count_encoding
# [13/84]Score: 44.941 -> 44.941 & unselected: drive_count_encoding
# [14/84]Score: 44.941 -> 44.941 & unselected: drive_median_encoding
# [15/84]Score: 44.941 -> 44.964 & unselected: title_status_median_encoding
# [16/84]Score: 44.941 -> 44.746 &   selected: paint_color_std_encoding
# [17/84]Score: 44.746 -> 45.919 & unselected: region_category
# [18/84]Score: 44.746 -> 44.733 &   selected: fuel_max_encoding
# [19/84]Score: 44.733 -> 44.702 &   selected: paint_color_median_encoding
# [20/84]Score: 44.702 -> 44.702 & unselected: transmission_median_encoding
# [21/84]Score: 44.702 -> 44.702 & unselected: transmission_max_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [22/84]Score: 44.702 -> 44.697 &   selected: fuel_category
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [23/84]Score: 44.697 -> 44.697 & unselected: drive_min_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [24/84]Score: 44.697 -> 44.717 & unselected: size_count_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [25/84]Score: 44.697 -> 44.608 &   selected: type_median_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [26/84]Score: 44.608 -> 44.781 & unselected: region_min_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [27/84]Score: 44.608 -> 44.633 & unselected: size_median_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [28/84]Score: 44.608 -> 44.608 & unselected: drive_mean_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [29/84]Score: 44.608 -> 44.628 & unselected: size_min_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [30/84]Score: 44.608 -> 44.627 & unselected: title_status_max_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [31/84]Score: 44.608 -> 44.592 &   selected: fuel_mean_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [32/84]Score: 44.592 -> 44.498 &   selected: manufacturer_count_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [33/84]Score: 44.498 -> 44.531 & unselected: state_median_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [34/84]Score: 44.498 -> 44.491 &   selected: condition_median_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [35/84]Score: 44.491 -> 44.465 &   selected: paint_color_count_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [36/84]Score: 44.465 -> 44.457 &   selected: manufacturer_mean_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [37/84]Score: 44.457 -> 44.439 &   selected: size_category
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [38/84]Score: 44.439 -> 44.446 & unselected: manufacturer_median_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [39/84]Score: 44.439 -> 44.432 &   selected: type_std_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [40/84]Score: 44.432 -> 44.412 &   selected: state_mean_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [41/84]Score: 44.412 -> 44.387 &   selected: fuel_std_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [42/84]Score: 44.387 -> 44.461 & unselected: region_max_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [43/84]Score: 44.387 -> 44.425 & unselected: paint_color_category
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [44/84]Score: 44.387 -> 44.410 & unselected: condition_min_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [45/84]Score: 44.387 -> 44.508 & unselected: manufacturer_category
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [46/84]Score: 44.387 -> 44.388 & unselected: cylinders_count_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [47/84]Score: 44.387 -> 44.444 & unselected: title_status_count_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [48/84]Score: 44.387 -> 44.506 & unselected: region_median_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [49/84]Score: 44.387 -> 44.354 &   selected: cylinders_median_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [50/84]Score: 44.354 -> 44.354 & unselected: transmission_count_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [51/84]Score: 44.354 -> 44.323 &   selected: type_max_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [52/84]Score: 44.323 -> 44.357 & unselected: type_category
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [53/84]Score: 44.323 -> 44.331 & unselected: fuel_min_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [54/84]Score: 44.323 -> 44.406 & unselected: condition_count_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [55/84]Score: 44.323 -> 44.393 & unselected: condition_category
# [56/84]Score: 44.323 -> 44.422 & unselected: manufacturer_std_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [57/84]Score: 44.323 -> 44.702 & unselected: state_category
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [58/84]Score: 44.323 -> 44.323 & unselected: drive_max_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [59/84]Score: 44.323 -> 44.356 & unselected: paint_color_mean_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [60/84]Score: 44.323 -> 44.302 &   selected: size_mean_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [61/84]Score: 44.302 -> 44.342 & unselected: condition_std_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [62/84]Score: 44.302 -> 44.361 & unselected: cylinders_min_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [63/84]Score: 44.302 -> 44.337 & unselected: size_max_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [64/84]Score: 44.302 -> 44.406 & unselected: manufacturer_min_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [65/84]Score: 44.302 -> 44.369 & unselected: cylinders_max_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [66/84]Score: 44.302 -> 44.381 & unselected: state_max_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [67/84]Score: 44.302 -> 44.524 & unselected: region_mean_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [68/84]Score: 44.302 -> 44.332 & unselected: cylinders_std_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [69/84]Score: 44.302 -> 44.302 & unselected: size_std_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [70/84]Score: 44.302 -> 44.399 & unselected: state_std_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [71/84]Score: 44.302 -> 44.302 & unselected: drive_std_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [72/84]Score: 44.302 -> 44.335 & unselected: cylinders_category
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [73/84]Score: 44.302 -> 44.380 & unselected: paint_color_max_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [74/84]Score: 44.302 -> 44.355 & unselected: manufacturer_max_encoding
# [75/84]Score: 44.302 -> 44.350 & unselected: cylinders_mean_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [76/84]Score: 44.302 -> 44.302 & unselected: transmission_std_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [77/84]Score: 44.302 -> 44.328 & unselected: title_status_mean_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [78/84]Score: 44.302 -> 44.352 & unselected: type_mean_encoding
# [79/84]Score: 44.302 -> 44.302 & unselected: transmission_mean_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [80/84]Score: 44.302 -> 44.401 & unselected: state_count_encoding
# [81/84]Score: 44.302 -> 44.402 & unselected: region_std_encoding
# [LightGBM] [Warning] Met negative value in categorical features, will convert it to NaN
# [82/84]Score: 44.302 -> 44.302 & unselected: transmission_min_encoding
# [83/84]Score: 44.302 -> 44.382 & unselected: paint_color_min_encoding
# [84/84]Score: 44.302 -> 44.358 & unselected: type_min_encoding
# selected features: ['fuel_count_encoding', 'type_count_encoding', 'paint_color_std_encoding', 'manufacturer_count_encoding', 'fuel_category', 'transmission_category', 'cylinders_median_encoding', 'size_category', 'condition_mean_encoding', 'fuel_std_encoding', 'type_median_encoding', 'paint_color_median_encoding', 'fuel_mean_encoding', 'type_std_encoding', 'fuel_max_encoding', 'title_status_std_encoding', 'type_max_encoding', 'condition_median_encoding', 'state_mean_encoding', 'paint_color_count_encoding', 'manufacturer_mean_encoding', 'drive_category', 'size_mean_encoding', 'year', 'odometer']
# best_score: 44.302424561188325
# Saved selected features!
