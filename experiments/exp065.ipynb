# %%
# ===================================================================
#  Library
# ===================================================================
import numpy as np
import pandas as pd
import polars as pl

# %%
# ===================================================================
#  CFG
# ===================================================================
class CFG:
    seed = 42
    save_dir = "G:/マイドライブ/signate_StudentCup2023/exp/"
    data_dir = "G:/マイドライブ/signate_StudentCup2023/data/"
    filename = "exp065"

# %%
# ===================================================================
#  DataLoading and concat
# ===================================================================
filenames = [f"exp0{f}" for f in range(14, 24)] + [f"exp0{f}" for f in range(26, 36)] + [f"exp0{f}" for f in range(39, 49)]  + [f"exp0{f}" for f in range(55, 65)]

# oof_df
for i, filename in enumerate(filenames):
    path = CFG.save_dir+f"oof_df_{filename}.csv"
    if i == 0:
        oof_df = pl.read_csv(source=path, has_header=False).rename({"column_1":"id", "column_2":f"pred_{i}"})
    else:
        oof_df = oof_df.join(pl.read_csv(source=path, has_header=False).rename({"column_1":"id", "column_2":f"pred_{i}"}), 
                             on="id", how="left")
oof_df.write_csv(CFG.save_dir+f"oof_df_{CFG.filename}.csv")
display(oof_df.head())
        
# test_df
for i, filename in enumerate(filenames):
    path = CFG.save_dir+f"{filename}.csv"
    if i == 0:
        test_df = pl.read_csv(source=path, has_header=False).rename({"column_1":"id", "column_2":f"pred_{i}"})
    else:
        test_df = test_df.join(pl.read_csv(source=path, has_header=False).rename({"column_1":"id", "column_2":f"pred_{i}"}), 
                             on="id", how="left")
test_df.write_csv(CFG.save_dir+f"{CFG.filename}.csv")
display(test_df.head())
# Out:
# shape: (5, 41)
# ┌─────┬────────────┬────────────┬────────────┬───┬────────────┬────────────┬───────────┬───────────┐
# │ id  ┆ pred_0     ┆ pred_1     ┆ pred_2     ┆ … ┆ pred_36    ┆ pred_37    ┆ pred_38   ┆ pred_39   │
# │ --- ┆ ---        ┆ ---        ┆ ---        ┆   ┆ ---        ┆ ---        ┆ ---       ┆ ---       │
# │ i64 ┆ f64        ┆ f64        ┆ f64        ┆   ┆ f64        ┆ f64        ┆ f64       ┆ f64       │
# ╞═════╪════════════╪════════════╪════════════╪═══╪════════════╪════════════╪═══════════╪═══════════╡
# │ 2   ┆ 2954.24757 ┆ 2735.11008 ┆ 3288.64770 ┆ … ┆ 2966.91020 ┆ 3300.76801 ┆ 2975.3417 ┆ 2996.4499 │
# │     ┆ 3          ┆ 6          ┆ 9          ┆   ┆ 1          ┆ 6          ┆ 8         ┆ 11        │
# │ 25  ┆ 7931.46235 ┆ 6944.61644 ┆ 7214.90924 ┆ … ┆ 7533.36672 ┆ 7830.54398 ┆ 7985.3423 ┆ 7729.2902 │
# │     ┆ 1          ┆ 3          ┆            ┆   ┆ 2          ┆ 7          ┆ 79        ┆ 81        │
# │ 26  ┆ 5843.17270 ┆ 5827.25037 ┆ 6115.09636 ┆ … ┆ 4992.65221 ┆ 5649.66258 ┆ 6276.9420 ┆ 6394.8373 │
